# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import contextily as cx
import shapely.geometry as sg
import seaborn as sns
import ast
import folium
import os
import tensorflow as tf
from tqdm import tqdm

from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Reshape, RepeatVector, TimeDistributed, Bidirectional
from keras.layers import Conv2D, Flatten, Concatenate, Input
from keras.callbacks import EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Load Data

# %%
# load tacheometry in X direction
Y_x = pd.read_csv('../Data/TargetX.csv', index_col=0)

# %%
Y_x.shape
# Out:
# (5817, 42)

# %%
Y_y = pd.read_csv('../Data/TargetY.csv', index_col=0)

# %%
Y_y.shape
# Out:
# (5817, 42)

# %%
Y_z = pd.read_csv('../Data/TargetZ.csv', index_col=0)

# %%
# load cpt data with depth only between 7 and 11
cpt = pd.read_csv('../Data/CPT_train_v2.csv', index_col=0)

# %%
# only take objects that are in both dataset
Y_x = Y_x[Y_x['objectid'].isin(cpt.index)]
Y_y = Y_y[Y_y['objectid'].isin(cpt.index)]
Y_z = Y_z[Y_z['objectid'].isin(cpt.index)]

Y_x = Y_x.drop(['objectid', 'X_coordinate', 'Y_coordinate', 'segment'], axis=1)
Y_y = Y_y.drop(['objectid', 'X_coordinate', 'Y_coordinate', 'segment'], axis=1)
Y_z = Y_z.drop(['objectid', 'X_coordinate', 'Y_coordinate', 'segment'], axis=1)

# %%
Y_x.index.str[:7].unique()
# Out:
# Index(['BDG0101', 'BDG0202', 'DCG0101', 'DCG0202', 'DCG0302', 'GRW0101',
#        'HEG0302', 'HEG0401', 'HEG0802', 'HEG0901', 'KVV0602', 'KVV0702',
#        'KZG0301', 'KZG0302', 'LLG0102', 'LLG0202', 'LYG0501', 'LYG0601',
#        'NHG0201', 'OVW0601', 'PRG0301', 'PRG0401', 'PRG0402', 'SIN0501',
#        'SIN0502', 'SIN0601', 'SIN0602', 'SIN0701', 'WEG0201', 'WKN0101'],
#       dtype='object')

# %%
sat_ver = pd.read_csv('../Data/SatVer.csv', index_col=0)

# %%
sat_ver.shape
# Out:
# (30, 38)

# %%
sat_hor = pd.read_csv('../Data/SatHor.csv', index_col=0)

# %%
sat_ach = pd.read_csv('../Data/SatAch.csv', index_col=0)

# %% [markdown]
# # Functions

# %%
def scale_features(df):
    """Scale features to be between 0 and 1"""

    df = (df - df.min(axis=0)) / (df.max(axis=0) - df.min(axis=0))
    
    return df

# %%
def mase(y_true, y_pred):
    
    n_samples, n_timesteps = y_true.shape 
    scaling_factor = 1/(n_timesteps-1) * np.sum(np.abs(np.diff(y_true, axis=1)), axis=1)
    value = np.mean(np.abs(y_true - y_pred), axis=1) / scaling_factor
    
    return np.mean(value)

# %%
def create_window(df, input_width, label_width, shift, incl_cpt=False, tacheometry=True, df_cpt=None, incl_sat=False):
    """
    Create training batches of width input_width,
    and labels of width label_width
    """
    
    X = []
    X_ver = []
    X_hor = []
    X_ach = []
    Y = []

    # fix for input per measuring bolt, turns input into correct shape
    if isinstance(df, pd.Series):
        df = pd.DataFrame(df).T
        
    # account for varying months of last measurement
    df = df.dropna()
    
    # current object
    obj = df.index.str[:7][0]
        
    for i in range(len(df.columns)):
        
        # ensure enough values are left for the label
        if i+input_width+label_width <= len(df.columns):
            
            # add window to X
            X.append(df.iloc[:,i:i+input_width].values)

            X_ver.append(train_sat_ver.loc[obj].iloc[i:i+input_width]) # remove [:,] if working with mean of sat data!
            X_hor.append(train_sat_hor.loc[obj].iloc[i:i+input_width]) # add [:,] if working without mean of sat data!
            X_ach.append(train_sat_ach.loc[obj].iloc[i:i+input_width])
            
            # add label to Y
            Y.append(df.iloc[:,i+input_width:i+input_width+label_width].values)
    
    # shape (batch, time, features)
    X = np.array(X).reshape((len(X), input_width, df.shape[0]))
    Y = np.array(Y).reshape((len(X), label_width, df.shape[0]))

    X_ver = np.expand_dims(np.array(X_ver), axis=2) # <- do this when working with mean of sat data
    X_hor = np.expand_dims(np.array(X_hor), axis=2)
    X_ach = np.expand_dims(np.array(X_ach), axis=2)

#     X_ver = np.array(X_ver).reshape((len(X), input_width, sat_ver.shape[0])) <- do this when not working with mean sat
#     X_hor = np.array(X_hor).reshape((len(X), input_width, sat_hor.shape[0]))
    
    X_ver = np.array(X_ver).reshape((len(X), input_width, 1))
    X_hor = np.array(X_hor).reshape((len(X), input_width, 1))
    X_ach = np.array(X_ach).reshape((len(X), input_width, 1))
    
    # only add cpt features if cpt data is passed
    if incl_cpt == True:

        cpt_array = np.array(df_cpt.values).reshape((1, 1, df_cpt.size))
        cpt_array = np.repeat(cpt_array, input_width, axis=1)
        cpt_array = np.repeat(cpt_array, len(X), axis=0)
        
        if tacheometry == False:
            X = cpt_array
        
        else:
            X = np.concatenate((X, cpt_array), axis=2)
            
    if incl_sat == True:
        
        X_sat = np.concatenate((X_ver, X_hor), axis=2)
        X_sat = np.concatenate((X_sat, X_ach), axis=2)
        
        if incl_cpt == False and tacheometry == False:
            X = X_sat
            
        else:
            X = np.concatenate((X, X_sat), axis=2)
              
    return X, Y

# %%
def create_validation_set(X, Y, splits=4):
    """
    Takes windowed training set as input,
    Splits off validation set, size equals number of splits
    """
    
    # take first windows as training set
    X_train = X[:X.shape[0]-splits]
    Y_train = Y[:Y.shape[0]-splits]
    
    # take last windows as validation set
    X_val = X[X.shape[0]-splits:]
    Y_val = Y[Y.shape[0]-splits:]
    
    return X_train, Y_train, X_val, Y_val

# %%
def NaiveBaseline(X, Y):
    """
    Create baseline prediction with naive method.
    Gives the last value as prediction
    """

    # predict last 5 elements of X window
    Y_pred = X[:,-6:-1,0]
    
    # compare against the 5 Y values in label
    Y_act = Y[:,:,0]
    
    # return mae and rmse
    return mean_squared_error(Y_act, Y_pred, squared=False), mean_absolute_error(Y_act, Y_pred), mase(Y_act, Y_pred)

# %%
def train_objects(df, input_width, label_width, shift, epochs=100, incl_cpt=True, tacheometry=True, incl_sat=False, model=None):
    """
    Train models per object, making use of create_window().
    Possible with or without features, choice of model can be passed.
    """

    results = []
    models = []
        
    # iterate over objects
    for obj in tqdm(df.index.str[:7].unique()):
        
        if incl_cpt == True:
            X, Y = create_window(df[df.index.str.contains(obj)], input_width=input_width, label_width=label_width, \
                shift=shift, incl_cpt=incl_cpt, tacheometry=tacheometry, incl_sat=incl_sat, df_cpt=cpt[cpt.index.str.contains(obj)])
        
        if incl_cpt == False:
            X, Y = create_window(df[df.index.str.contains(obj)], input_width=input_width, label_width=label_width, \
                shift=shift, incl_cpt=False, tacheometry=tacheometry, incl_sat=incl_sat)

        train_X, train_Y, val_X, val_Y = create_validation_set(X, Y)
                
        # if 'naive' is passed as model, naive model is stored in results
        if model == "naive":
            results.append(NaiveBaseline(val_X, val_Y))
            
        # otherwise, BiLSTM model is trained and stored in results
        else:
            model = initiate_model(label_width, output_length=Y.shape[2])
            results.append(model.fit(train_X, train_Y, validation_data=(val_X, val_Y), epochs=epochs, verbose=0, callbacks=[EarlyStopping(monitor='val_mean_absolute_error', patience=20, restore_best_weights=True)]))
            models.append(model)
        
    return models, results

# %%
def initiate_model(label_width, output_length):
    """
    Initiate and compile model
    """
    model = Sequential()
    model.add(Bidirectional(LSTM(64, activation = 'relu')))
    model.add(Reshape((1, -1)))    
    model.add(Dense(units=label_width * output_length))
    model.add(Reshape((label_width, output_length)))  
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.RootMeanSquaredError(), \
                                                        tf.keras.metrics.MeanAbsolutePercentageError()])
    return model

# %%
# train tcmt only on data per bout, grouped per rak, grouped per wall
def grouping_experiment(df, group, features=False):
    """
    variable group should have value 'wall', 'rak', or 'total'
    """
    
    results = []

    if group == 'total':
        X, Y = create_window(df, input_width=10, label_width=5, shift=1)
        
        train_X, train_Y, val_X, val_Y = create_validation_set(X, Y)
        model = initiate_model(5, X.shape[2])
        results.append(model.fit(train_X, train_Y, validation_data=(val_X, val_Y), epochs=100, verbose=1))
        
        return model, results
        
    else:
        if group == 'rak':
            objects = df.index.str[:7].unique()
        elif group == 'wall':
            objects = df.index.str[:3].unique()
   
        for obj in tqdm(objects):

            if features == True:
                X, Y = create_window(df[df.index.str.contains(obj)], input_width=10, label_width=5, shift=1, features=True, df_cpt=train_cpt[cpt.index.str.contains(obj)].iloc[0])
            else:
                X, Y = create_window(df[df.index.str.contains(obj)], input_width=10, label_width=5, shift=1)

            train_X, train_Y, val_X, val_Y = create_validation_set(X, Y)
            model = initiate_model(5, X.shape[2])
            results.append(model.fit(train_X, train_Y, validation_data=(val_X, val_Y), epochs=100, verbose=0, \
                                     callbacks=[EarlyStopping(monitor='val_mean_absolute_error', patience=10, restore_best_weights=True)]))    

    return results

# %%
def initiate_incremental(input_shape_bilstm, input_shape_new_data, label_width, outcome_length):
    """
    This function initiates and compiles an incrementally fused model
    """
    
    # Create BiLSTM model
    input_bilstm = Input(shape=input_shape_bilstm)
    bilstm = Bidirectional(LSTM(units=64, return_sequences=True))(input_bilstm)
    model_bilstm = Model(inputs=input_bilstm, outputs=bilstm)

    # Create layer for new data
    input_new_data = Input(shape=input_shape_new_data)
    new_data = Dense(units=128)(input_new_data)
    model_new_data = Model(inputs=input_new_data, outputs=new_data)

    # Concatenate BiLSTM output and new data
    merged_model = Concatenate()([model_bilstm.output, model_new_data.output])

    # Add fully connected layer
    merged_model = Dense(units=256, activation='relu')(merged_model)
    
    # Add BiLSTM layer
    merged_model = Bidirectional(LSTM(units=64, return_sequences=True))(merged_model)
    
    # Output layer
    merged_model = Reshape((1, -1))(merged_model)
    merged_model = Dense(units=label_width * outcome_length)(merged_model)
    merged_model = Reshape((label_width, outcome_length))(merged_model)

    # Create the final model
    model = Model(inputs=[model_bilstm.input, model_new_data.input], outputs=merged_model)

    # Compile the model
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.RootMeanSquaredError()])

    return model

# %%
def incremental_fusion(first_dataset, direction, tacheometry=False):
    """
    This function yields an incrementally fused model.
    """
    
    results_inc = []
    models_inc = []
    
    # set df to corresponding direction
    if direction == 'X':
        df = train_Yx
    if direction == 'Y':
        df = train_Yy
    if direction == 'Z':
        df = train_Yz
        
    # define whether tacheometry data should be added to the windows or not
    sat_tcmt = False
    cpt_tcmt = False
    if tacheometry == True:
        if first_dataset == 'CPT':
            cpt_tcmt = True
        else:
            sat_tcmt = True
        
    # iterate over objects
    for obj in tqdm(df.index.str[:7].unique()):
        
        # create windows for satellite data
        X_sat, Y_sat = create_window(df[df.index.str.contains(obj)], input_width=10, label_width=5, \
            shift=1, incl_cpt=False, tacheometry=sat_tcmt, incl_sat=True)

        # create windows for CPT data
        X_cpt, Y_cpt = create_window(df[df.index.str.contains(obj)], input_width=10, label_width=5, \
            shift=1, incl_cpt=True, tacheometry=cpt_tcmt, incl_sat=False, df_cpt=cpt[cpt.index.str.contains(obj)].iloc[0])

        # create validation set
        train_X_sat, train_Y_sat, val_X_sat, val_Y_sat = create_validation_set(X_sat, Y_sat)
        train_X_cpt, train_Y_cpt, val_X_cpt, val_Y_cpt = create_validation_set(X_cpt, Y_cpt)
                
        label_width=Y_sat.shape[1]
        outcome_length=Y_sat.shape[2]
                    
        # pass CPT as first dataset
        if first_dataset == 'CPT':
            model = initiate_incremental(train_X_cpt.shape[1:], train_X_sat.shape[1:], label_width, outcome_length)
            results_inc.append(model.fit([train_X_cpt, train_X_sat], train_Y_sat, validation_data=([val_X_cpt, val_X_sat], \
                            val_Y_sat), epochs=100, verbose=0, callbacks=[EarlyStopping(monitor='val_mean_absolute_error', patience=20, restore_best_weights=True)]))
            models_inc.append(model)
            
        # pass Sat as first dataset
        else:
            model = initiate_incremental(train_X_sat.shape[1:], train_X_cpt.shape[1:], label_width, outcome_length)
            results_inc.append(model.fit([train_X_sat, train_X_cpt], train_Y_sat, validation_data=([val_X_sat, val_X_cpt], \
                            val_Y_sat), epochs=100, verbose=0, callbacks=[EarlyStopping(monitor='val_mean_absolute_error', patience=20, restore_best_weights=True)]))
            models_inc.append(model)
            
    return models_inc, results_inc

# %%
def visualize_performance(results):
    """
    Visualizes the MAE and RMSE per epoch given a list of results
    """
    
    maes_train = []
    maes_val = []
    rmse_train = []
    rmse_val = []

    for i, result in enumerate(results):
        
        print(np.min(np.array(result.history['val_mean_absolute_error'])))
        
        # store MAE
        if 'val_mean_absolute_error' in result.history.keys():
            maes_train.append(result.history['mean_absolute_error'])
            maes_val.append(result.history['val_mean_absolute_error'])
            
        # store RMSE
        if 'val_root_mean_squared_error' in result.history.keys():
            rmse_train.append(result.history['root_mean_squared_error'])
            rmse_val.append(result.history['val_root_mean_squared_error'])
            
    # calculate mean values
    mean_mae_train = np.mean(np.array(maes_train), axis=0)
    mean_mae_val = np.mean(np.array(maes_val), axis=0)
    mean_rmse_train = np.mean(np.array(rmse_train), axis=0)
    mean_rmse_val = np.mean(np.array(rmse_val), axis=0)
            
    print(f'Optimal Mean MAE: {np.min(mean_mae_val)} @ epoch {np.argmin(mean_mae_val)}')
    print(f'Optimal Mean RMSE: {np.min(mean_rmse_val)} @ epoch {np.argmin(mean_rmse_val)}')
    
    # plot MAE scores
    sns.lineplot(data=mean_mae_train, label='train')
    sns.lineplot(data=mean_mae_val, label='validation')
    plt.title('Mean MAE scores of BiLSTM model')
    plt.ylabel('MAE')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()

    # plot RMSE scores
    sns.lineplot(data=mean_rmse_train, label='train')
    sns.lineplot(data=mean_rmse_val, label='validation')
    plt.title('Mean RMSE scores of BiLSTM model')
    plt.ylabel('RMSE')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()
    
    return

# %%
def val_metrics(direction, models, input_width, label_width, shift, incl_cpt=False, incl_sat=False, tacheometry=False, incremental=False, incremental_first='CPT'):
    
    # set df to corresponding direction
    if direction == 'X':
        df = train_Yx
                
    if direction == 'Y':
        df = train_Yy
        
    if direction == 'Z':
        df = train_Yz
        
    val_rmse = []
    val_mae = []
    val_mase = []
    val_r2 = []
    
    for i, obj in enumerate(df.index.str[:7].unique()):

        X, Y = create_window(df[df.index.str.contains(obj)], input_width, label_width, shift, incl_cpt=incl_cpt, \
                                     incl_sat=incl_sat, tacheometry=tacheometry, df_cpt=cpt[cpt.index.str.contains(obj)])
        train_X, train_Y, val_X, val_Y = create_validation_set(X, Y)
        
        model = models[i]

        if incremental == True:

            X_cpt2, Y_cpt2 = create_window(df[df.index.str.contains(obj)], input_width, label_width, shift, incl_cpt=True, \
                                           tacheometry=False, df_cpt=cpt[cpt.index.str.contains(obj)])
            train_X_cpt2, train_Y_cpt2, val_X_cpt2, val_Y_cpt2 = create_validation_set(X_cpt2, Y_cpt2)           

            X_sat2, Y_sat2 = create_window(df[df.index.str.contains(obj)], input_width, label_width, shift, incl_cpt=False, \
                                           tacheometry=False, incl_sat=True)
            train_X_sat2, train_Y_sat2, val_X_sat2, val_Y_sat2 = create_validation_set(X_sat2, Y_sat2)
        
            if incremental_first == 'CPT':
                predictions = model.predict([val_X, val_X_sat2])
            else:
                predictions = model.predict([val_X, val_X_cpt2])
                
        else:
            predictions = model.predict(val_X)
        
        rmses = []
        maes = []
        mases = []
        r2s = []

        for j in range(predictions.shape[2]):
            maes.append(mean_absolute_error(val_Y[:,:,j], predictions[:,:,j]))
            mases.append(mase(val_Y[:,:,j], predictions[:,:,j]))
            r2s.append(r2_score(val_Y[:,:,j], predictions[:,:,j]))

            y_act = tf.constant(val_Y[:,:,j])
            y_pred = tf.constant(predictions[:,:,j])
            
            rmse = tf.keras.metrics.RootMeanSquaredError()
            rmse_value = rmse(y_act, y_pred).numpy()
            rmses.append(rmse_value)

        val_rmse.append(np.mean(rmses))
        val_mae.append(np.mean(maes))
        val_mase.append(np.mean(mases))
        val_r2.append(np.mean(r2s))
        
    return np.mean(val_rmse), np.mean(val_mae), np.mean(val_mase), np.mean(val_r2)

# %%
def save_models(results, combi, direction):
    """
    Save models
    """
    for i, mod in tqdm(enumerate(results[0])):
        obj = train_Yx.index.str[:7].unique()[i]
        mod.save(f'../Models/{combi}/{direction}/{obj}')
        
    return 'Models are saved successfully.'

# %%
def load_models(combi, direction):
    """
    Load models
    """
    models = []
    directory = f'../Models/{combi}/{direction}'
    
    for file in tqdm(os.listdir(directory)):
        models.append(tf.keras.models.load_model(f'{directory}/{file}'))

    return models

# %%
def late_fusion(direction, tacheometry=False, incremental=False):

    # set df to corresponding direction
    if direction == 'X':
        df = train_Yx
        if tacheometry == False:
            if incremental == False:
                models1 = results_cpt_x[0]
                models2 = results_sat_x[0]
            else:
                models1 = results_inc_cpt_sat_x[0]
                models2 = results_inc_sat_cpt_x[0]
        else:
            if incremental == False:
                models1 = results_tcmt_cpt_x[0]
                models2 = results_tcmt_sat_x[0]
            else:
                models1 = results_inc_tcmt_cpt_sat_x[0]
                models2 = results_inc_tcmt_sat_cpt_x[0]   
                
    if direction == 'Y':
        df = train_Yy
        if tacheometry == False:
            if incremental == False:
                models1 = results_cpt_y[0]
                models2 = results_sat_y[0]
            else:
                models1 = results_inc_cpt_sat_y[0]
                models2 = results_inc_sat_cpt_y[0]
        else:
            if incremental == False:
                models1 = results_tcmt_cpt_y[0]
                models2 = results_tcmt_sat_y[0]
            else:
                models1 = results_inc_tcmt_cpt_sat_y[0]
                models2 = results_inc_tcmt_sat_cpt_y[0]
                
    if direction == 'Z':
        df = train_Yz
        if tacheometry == False:
            if incremental == False:
                models1 = results_cpt_z[0]
                models2 = results_sat_z[0]
            else:
                models1 = results_inc_cpt_sat_z[0]
                models2 = results_inc_sat_cpt_z[0]
        else:
            if incremental == False:
                models1 = results_tcmt_cpt_z[0]
                models2 = results_tcmt_sat_z[0]
            else:
                models1 = results_inc_tcmt_cpt_sat_z[0]
                models2 = results_inc_tcmt_sat_cpt_z[0] 

    val_mae = []
    val_rmse = []
    val_mase = []

    for i, obj in enumerate(df.index.str[:7].unique()):

        X_cpt, Y_cpt = create_window(df[df.index.str.contains(obj)], 10, 5, 1, incl_cpt=True, tacheometry=tacheometry, df_cpt=cpt[cpt.index.str.contains(obj)].iloc[0])
        train_X_cpt, train_Y_cpt, val_X_cpt, val_Y_cpt = create_validation_set(X_cpt, Y_cpt)

        X_sat, Y_sat = create_window(df[df.index.str.contains(obj)], 10, 5, 1, incl_cpt=False, tacheometry=tacheometry, incl_sat=True)
        train_X_sat, train_Y_sat, val_X_sat, val_Y_sat = create_validation_set(X_sat, Y_sat)

        model1 = models1[i]
        model2 = models2[i]

        
        if incremental == True:
            
            X_cpt2, Y_cpt2 = create_window(df[df.index.str.contains(obj)], 10, 5, 1, incl_cpt=True, tacheometry=False, df_cpt=cpt[cpt.index.str.contains(obj)].iloc[0])
            train_X_cpt2, train_Y_cpt2, val_X_cpt2, val_Y_cpt2 = create_validation_set(X_cpt2, Y_cpt2)           
        
            X_sat2, Y_sat2 = create_window(df[df.index.str.contains(obj)], 10, 5, 1, incl_cpt=False, tacheometry=False, incl_sat=True)
            train_X_sat2, train_Y_sat2, val_X_sat2, val_Y_sat2 = create_validation_set(X_sat2, Y_sat2)
            
            predictions1 = model1.predict([val_X_cpt, val_X_sat2])
            predictions2 = model2.predict([val_X_sat, val_X_cpt2])
        else:
            predictions1 = model1.predict(val_X_cpt)
            predictions2 = model2.predict(val_X_sat)

        predictions = (predictions1 + predictions2) / 2

        maes = []
        rmses = []
        mases = []

        for j in range(predictions.shape[2]):
            maes.append(mean_absolute_error(val_Y_cpt[:,:,j], predictions[:,:,j]))
            mases.append(mase(val_Y_cpt[:,:,j], predictions[:,:,j]))

            y_act = tf.constant(val_Y_cpt[:,:,j])
            y_pred = tf.constant(predictions[:,:,j])
            rmse = tf.keras.metrics.RootMeanSquaredError()
            rmse_value = rmse(y_act, y_pred).numpy()
            rmses.append(rmse_value)

        val_mae.append(np.mean(maes))
        val_rmse.append(np.mean(rmses))
        val_mase.append(np.mean(mases))

    return np.mean(val_rmse), np.mean(val_mae), np.mean(val_mase)

# %% [markdown]
# # Train/Val/Test split

# %%
# set random seeds for reproducable results
np.random.seed(42)
tf.random.set_seed(42)

# %%
cpt = scale_features(cpt)

# %%
# Train on 70% of the objects and 75% of the timeseries
train_Yx = Y_x[0:int(0.7*len(Y_x))].iloc[:, 0:int(0.75*len(Y_x.columns))]
train_Yy = Y_y[0:int(0.7*len(Y_y))].iloc[:, 0:int(0.75*len(Y_y.columns))]
train_Yz = Y_z[0:int(0.7*len(Y_z))].iloc[:, 0:int(0.75*len(Y_z.columns))]

# test on 70% of the objects and 75% of the timeseries
test_Yx = Y_x[0:int(0.7*len(Y_x))].iloc[:, int(0.75*len(Y_x.columns)):]

# test on 30% of the object later

# %%
train_Yx.shape
# Out:
# (1163, 28)

# %%
len(train_Yx.index.str[:7].unique())
# Out:
# 20

# %%
train_sat_ver = sat_ver.iloc[:, 0:int(0.75*len(sat_ver.columns))]
train_sat_hor = sat_hor.iloc[:, 0:int(0.75*len(sat_hor.columns))]
train_sat_ach = sat_ach.iloc[:, 0:int(0.75*len(sat_ach.columns))]

train_sat_ver.shape, train_sat_hor.shape, train_sat_ach.shape
# Out:
# ((30, 28), (30, 28), (30, 28))

# %%
X0, Y0 = create_window(train_Yx.iloc[0], input_width=10, label_width=5, shift=1, incl_cpt=True, df_cpt=cpt)

# %%
train_X0, train_Y0, val_X0, val_Y0 = create_validation_set(X0, Y0)

# %%
train_X0.shape, train_Y0.shape, val_X0.shape, val_Y0.shape
# Out:
# ((10, 10, 511), (10, 5, 1), (4, 10, 511), (4, 5, 1))

# %% [markdown]
# # Check if everything works

# %%
model = initiate_model(5, output_length=val_Y0.shape[2])

# %%
result = model.fit(train_X0, train_Y0, validation_data=(val_X0, val_Y0), epochs=100, verbose=1, callbacks=[EarlyStopping(monitor='val_mean_absolute_error', patience=20, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 1.2722 - mean_absolute_error: 1.0351 - root_mean_squared_error: 1.1279 - mean_absolute_percentage_error: 105.1333 - val_loss: 2.2287 - val_mean_absolute_error: 1.3243 - val_root_mean_squared_error: 1.4929 - val_mean_absolute_percentage_error: 72.8774
# Epoch 2/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4039 - mean_absolute_error: 0.5701 - root_mean_squared_error: 0.6355 - mean_absolute_percentage_error: 56.9370 - val_loss: 0.9524 - val_mean_absolute_error: 0.8117 - val_root_mean_squared_error: 0.9759 - val_mean_absolute_percentage_error: 42.1109
# Epoch 3/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0567 - mean_absolute_error: 0.1958 - root_mean_squared_error: 0.2381 - mean_absolute_percentage_error: 20.0440 - val_loss: 0.3436 - val_mean_absolute_error: 0.4596 - val_root_mean_squared_error: 0.5861 - val_mean_absolute_percentage_error: 25.1105
# Epoch 4/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3419 - mean_absolute_error: 0.5214 - root_mean_squared_error: 0.5847 - mean_absolute_percentage_error: 57.2149 - val_loss: 0.5051 - val_mean_absolute_error: 0.5325 - val_root_mean_squared_error: 0.7107 - val_mean_absolute_percentage_error: 27.1761
# Epoch 5/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2272 - mean_absolute_error: 0.3783 - root_mean_squared_error: 0.4766 - mean_absolute_percentage_error: 41.6357 - val_loss: 0.7847 - val_mean_absolute_error: 0.6867 - val_root_mean_squared_error: 0.8858 - val_mean_absolute_percentage_error: 34.3768
# Epoch 6/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1052 - mean_absolute_error: 0.2520 - root_mean_squared_error: 0.3243 - mean_absolute_percentage_error: 26.7462 - val_loss: 1.0355 - val_mean_absolute_error: 0.8021 - val_root_mean_squared_error: 1.0176 - val_mean_absolute_percentage_error: 39.9026
# Epoch 7/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0652 - mean_absolute_error: 0.2065 - root_mean_squared_error: 0.2554 - mean_absolute_percentage_error: 21.6394 - val_loss: 1.2126 - val_mean_absolute_error: 0.8811 - val_root_mean_squared_error: 1.1012 - val_mean_absolute_percentage_error: 44.0090
# Epoch 8/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0641 - mean_absolute_error: 0.2057 - root_mean_squared_error: 0.2532 - mean_absolute_percentage_error: 20.5551 - val_loss: 1.3136 - val_mean_absolute_error: 0.9199 - val_root_mean_squared_error: 1.1461 - val_mean_absolute_percentage_error: 45.9707
# Epoch 9/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0789 - mean_absolute_error: 0.2281 - root_mean_squared_error: 0.2809 - mean_absolute_percentage_error: 22.2950 - val_loss: 1.3596 - val_mean_absolute_error: 0.9306 - val_root_mean_squared_error: 1.1660 - val_mean_absolute_percentage_error: 46.3449
# Epoch 10/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0951 - mean_absolute_error: 0.2385 - root_mean_squared_error: 0.3084 - mean_absolute_percentage_error: 23.2923 - val_loss: 1.3601 - val_mean_absolute_error: 0.9263 - val_root_mean_squared_error: 1.1662 - val_mean_absolute_percentage_error: 46.0151
# Epoch 11/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1024 - mean_absolute_error: 0.2431 - root_mean_squared_error: 0.3199 - mean_absolute_percentage_error: 23.9507 - val_loss: 1.3279 - val_mean_absolute_error: 0.9178 - val_root_mean_squared_error: 1.1523 - val_mean_absolute_percentage_error: 45.7161
# Epoch 12/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0979 - mean_absolute_error: 0.2392 - root_mean_squared_error: 0.3129 - mean_absolute_percentage_error: 23.6890 - val_loss: 1.2692 - val_mean_absolute_error: 0.9038 - val_root_mean_squared_error: 1.1266 - val_mean_absolute_percentage_error: 45.2687
# Epoch 13/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0848 - mean_absolute_error: 0.2271 - root_mean_squared_error: 0.2912 - mean_absolute_percentage_error: 22.4999 - val_loss: 1.1927 - val_mean_absolute_error: 0.8865 - val_root_mean_squared_error: 1.0921 - val_mean_absolute_percentage_error: 44.7921
# Epoch 14/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0686 - mean_absolute_error: 0.2106 - root_mean_squared_error: 0.2620 - mean_absolute_percentage_error: 20.8849 - val_loss: 1.1068 - val_mean_absolute_error: 0.8630 - val_root_mean_squared_error: 1.0521 - val_mean_absolute_percentage_error: 43.9339
# Epoch 15/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0541 - mean_absolute_error: 0.1915 - root_mean_squared_error: 0.2325 - mean_absolute_percentage_error: 19.0960 - val_loss: 1.0216 - val_mean_absolute_error: 0.8322 - val_root_mean_squared_error: 1.0108 - val_mean_absolute_percentage_error: 42.4687
# Epoch 16/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0435 - mean_absolute_error: 0.1718 - root_mean_squared_error: 0.2086 - mean_absolute_percentage_error: 17.3930 - val_loss: 0.9439 - val_mean_absolute_error: 0.7965 - val_root_mean_squared_error: 0.9715 - val_mean_absolute_percentage_error: 40.4713
# Epoch 17/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0370 - mean_absolute_error: 0.1585 - root_mean_squared_error: 0.1924 - mean_absolute_percentage_error: 16.5115 - val_loss: 0.8792 - val_mean_absolute_error: 0.7623 - val_root_mean_squared_error: 0.9377 - val_mean_absolute_percentage_error: 38.4190
# Epoch 18/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0339 - mean_absolute_error: 0.1524 - root_mean_squared_error: 0.1842 - mean_absolute_percentage_error: 16.3463 - val_loss: 0.8321 - val_mean_absolute_error: 0.7350 - val_root_mean_squared_error: 0.9122 - val_mean_absolute_percentage_error: 36.7097
# Epoch 19/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0341 - mean_absolute_error: 0.1543 - root_mean_squared_error: 0.1845 - mean_absolute_percentage_error: 16.8614 - val_loss: 0.8046 - val_mean_absolute_error: 0.7079 - val_root_mean_squared_error: 0.8970 - val_mean_absolute_percentage_error: 34.7145
# Epoch 20/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0373 - mean_absolute_error: 0.1611 - root_mean_squared_error: 0.1931 - mean_absolute_percentage_error: 17.8545 - val_loss: 0.7956 - val_mean_absolute_error: 0.6886 - val_root_mean_squared_error: 0.8919 - val_mean_absolute_percentage_error: 33.1326
# Epoch 21/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0421 - mean_absolute_error: 0.1698 - root_mean_squared_error: 0.2052 - mean_absolute_percentage_error: 19.0755 - val_loss: 0.8002 - val_mean_absolute_error: 0.6788 - val_root_mean_squared_error: 0.8946 - val_mean_absolute_percentage_error: 32.1673
# Epoch 22/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0444 - mean_absolute_error: 0.1736 - root_mean_squared_error: 0.2107 - mean_absolute_percentage_error: 19.7376 - val_loss: 0.8139 - val_mean_absolute_error: 0.6799 - val_root_mean_squared_error: 0.9022 - val_mean_absolute_percentage_error: 31.9813
# Epoch 23/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0411 - mean_absolute_error: 0.1672 - root_mean_squared_error: 0.2028 - mean_absolute_percentage_error: 19.1885 - val_loss: 0.8361 - val_mean_absolute_error: 0.6909 - val_root_mean_squared_error: 0.9144 - val_mean_absolute_percentage_error: 32.5197

# %%
sns.lineplot(data=result.history['mean_absolute_error'], label='train')
sns.lineplot(data=result.history['val_mean_absolute_error'], label='validation')
plt.title('MAE scores')
plt.ylabel('MAE')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# # Experiments

# %% [markdown]
# ### Training per wall/rak/bout

# %%
results_rak = grouping_experiment(train_Yx, 'rak')
results_wall = grouping_experiment(train_Yx, 'wall')
results_total = grouping_experiment(train_Yx, 'total')
# Out:
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 6.7530 - mean_absolute_error: 1.9290 - root_mean_squared_error: 2.5986 - val_loss: 11.6449 - val_mean_absolute_error: 2.7728 - val_root_mean_squared_error: 3.4125
# Epoch 2/100
# 1/1 [==============================] - 0s 28ms/step - loss: 6.5130 - mean_absolute_error: 1.8837 - root_mean_squared_error: 2.5520 - val_loss: 11.3141 - val_mean_absolute_error: 2.7276 - val_root_mean_squared_error: 3.3636
# Epoch 3/100
# 1/1 [==============================] - 0s 38ms/step - loss: 6.2872 - mean_absolute_error: 1.8395 - root_mean_squared_error: 2.5074 - val_loss: 11.0073 - val_mean_absolute_error: 2.6857 - val_root_mean_squared_error: 3.3177
# Epoch 4/100
# 1/1 [==============================] - 0s 33ms/step - loss: 6.0659 - mean_absolute_error: 1.7951 - root_mean_squared_error: 2.4629 - val_loss: 10.7074 - val_mean_absolute_error: 2.6452 - val_root_mean_squared_error: 3.2722
# Epoch 5/100
# 1/1 [==============================] - 0s 32ms/step - loss: 5.8408 - mean_absolute_error: 1.7496 - root_mean_squared_error: 2.4168 - val_loss: 10.4017 - val_mean_absolute_error: 2.6041 - val_root_mean_squared_error: 3.2252
# Epoch 6/100
# 1/1 [==============================] - 0s 29ms/step - loss: 5.6042 - mean_absolute_error: 1.7013 - root_mean_squared_error: 2.3673 - val_loss: 10.0786 - val_mean_absolute_error: 2.5595 - val_root_mean_squared_error: 3.1747
# Epoch 7/100
# 1/1 [==============================] - 0s 28ms/step - loss: 5.3498 - mean_absolute_error: 1.6501 - root_mean_squared_error: 2.3130 - val_loss: 9.7318 - val_mean_absolute_error: 2.5097 - val_root_mean_squared_error: 3.1196
# Epoch 8/100
# 1/1 [==============================] - 0s 37ms/step - loss: 5.0711 - mean_absolute_error: 1.5937 - root_mean_squared_error: 2.2519 - val_loss: 9.3625 - val_mean_absolute_error: 2.4520 - val_root_mean_squared_error: 3.0598
# Epoch 9/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.7620 - mean_absolute_error: 1.5303 - root_mean_squared_error: 2.1822 - val_loss: 8.9840 - val_mean_absolute_error: 2.3848 - val_root_mean_squared_error: 2.9973
# Epoch 10/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.4217 - mean_absolute_error: 1.4629 - root_mean_squared_error: 2.1028 - val_loss: 8.6366 - val_mean_absolute_error: 2.3118 - val_root_mean_squared_error: 2.9388
# Epoch 11/100
# 1/1 [==============================] - 0s 37ms/step - loss: 4.0572 - mean_absolute_error: 1.3949 - root_mean_squared_error: 2.0142 - val_loss: 8.4199 - val_mean_absolute_error: 2.2522 - val_root_mean_squared_error: 2.9017
# Epoch 12/100
# 1/1 [==============================] - 0s 38ms/step - loss: 3.6916 - mean_absolute_error: 1.3336 - root_mean_squared_error: 1.9213 - val_loss: 8.5523 - val_mean_absolute_error: 2.2474 - val_root_mean_squared_error: 2.9244
# Epoch 13/100
# 1/1 [==============================] - 0s 36ms/step - loss: 3.3817 - mean_absolute_error: 1.2918 - root_mean_squared_error: 1.8389 - val_loss: 9.2261 - val_mean_absolute_error: 2.3105 - val_root_mean_squared_error: 3.0374
# Epoch 14/100
# 1/1 [==============================] - 0s 39ms/step - loss: 3.2037 - mean_absolute_error: 1.2862 - root_mean_squared_error: 1.7899 - val_loss: 9.8962 - val_mean_absolute_error: 2.3726 - val_root_mean_squared_error: 3.1458
# Epoch 15/100
# 1/1 [==============================] - 0s 40ms/step - loss: 3.0912 - mean_absolute_error: 1.2813 - root_mean_squared_error: 1.7582 - val_loss: 10.0158 - val_mean_absolute_error: 2.3635 - val_root_mean_squared_error: 3.1648
# Epoch 16/100
# 1/1 [==============================] - 0s 42ms/step - loss: 2.8927 - mean_absolute_error: 1.2356 - root_mean_squared_error: 1.7008 - val_loss: 9.7174 - val_mean_absolute_error: 2.3109 - val_root_mean_squared_error: 3.1173
# Epoch 17/100
# 1/1 [==============================] - 0s 36ms/step - loss: 2.6228 - mean_absolute_error: 1.1563 - root_mean_squared_error: 1.6195 - val_loss: 9.3159 - val_mean_absolute_error: 2.2515 - val_root_mean_squared_error: 3.0522
# Epoch 18/100
# 1/1 [==============================] - 0s 40ms/step - loss: 2.3623 - mean_absolute_error: 1.0704 - root_mean_squared_error: 1.5370 - val_loss: 9.0170 - val_mean_absolute_error: 2.2053 - val_root_mean_squared_error: 3.0028
# Epoch 19/100
# 1/1 [==============================] - 0s 41ms/step - loss: 2.1536 - mean_absolute_error: 0.9943 - root_mean_squared_error: 1.4675 - val_loss: 8.8917 - val_mean_absolute_error: 2.1772 - val_root_mean_squared_error: 2.9819
# Epoch 20/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.9922 - mean_absolute_error: 0.9326 - root_mean_squared_error: 1.4115 - val_loss: 8.9515 - val_mean_absolute_error: 2.1728 - val_root_mean_squared_error: 2.9919
# Epoch 21/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8567 - mean_absolute_error: 0.8857 - root_mean_squared_error: 1.3626 - val_loss: 9.1986 - val_mean_absolute_error: 2.1948 - val_root_mean_squared_error: 3.0329
# Epoch 22/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7287 - mean_absolute_error: 0.8480 - root_mean_squared_error: 1.3148 - val_loss: 9.6681 - val_mean_absolute_error: 2.2483 - val_root_mean_squared_error: 3.1094
# Epoch 23/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.5997 - mean_absolute_error: 0.8169 - root_mean_squared_error: 1.2648 - val_loss: 10.4381 - val_mean_absolute_error: 2.3336 - val_root_mean_squared_error: 3.2308
# Epoch 24/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4721 - mean_absolute_error: 0.7919 - root_mean_squared_error: 1.2133 - val_loss: 11.6307 - val_mean_absolute_error: 2.4533 - val_root_mean_squared_error: 3.4104
# Epoch 25/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3569 - mean_absolute_error: 0.7742 - root_mean_squared_error: 1.1648 - val_loss: 13.2965 - val_mean_absolute_error: 2.6022 - val_root_mean_squared_error: 3.6464
# Epoch 26/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2657 - mean_absolute_error: 0.7633 - root_mean_squared_error: 1.1250 - val_loss: 15.0347 - val_mean_absolute_error: 2.7367 - val_root_mean_squared_error: 3.8775
# Epoch 27/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1925 - mean_absolute_error: 0.7509 - root_mean_squared_error: 1.0920 - val_loss: 16.0377 - val_mean_absolute_error: 2.7944 - val_root_mean_squared_error: 4.0047
# Epoch 28/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1147 - mean_absolute_error: 0.7265 - root_mean_squared_error: 1.0558 - val_loss: 15.9040 - val_mean_absolute_error: 2.7593 - val_root_mean_squared_error: 3.9880
# Epoch 29/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0306 - mean_absolute_error: 0.6907 - root_mean_squared_error: 1.0152 - val_loss: 15.1428 - val_mean_absolute_error: 2.6849 - val_root_mean_squared_error: 3.8914
# Epoch 30/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9618 - mean_absolute_error: 0.6569 - root_mean_squared_error: 0.9807 - val_loss: 14.4192 - val_mean_absolute_error: 2.6175 - val_root_mean_squared_error: 3.7973
# Epoch 31/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9179 - mean_absolute_error: 0.6332 - root_mean_squared_error: 0.9580 - val_loss: 14.0523 - val_mean_absolute_error: 2.5804 - val_root_mean_squared_error: 3.7486
# Epoch 32/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8886 - mean_absolute_error: 0.6186 - root_mean_squared_error: 0.9427 - val_loss: 14.0850 - val_mean_absolute_error: 2.5742 - val_root_mean_squared_error: 3.7530
# Epoch 33/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.8627 - mean_absolute_error: 0.6084 - root_mean_squared_error: 0.9288 - val_loss: 14.4269 - val_mean_absolute_error: 2.5921 - val_root_mean_squared_error: 3.7983
# Epoch 34/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8385 - mean_absolute_error: 0.6000 - root_mean_squared_error: 0.9157 - val_loss: 14.7994 - val_mean_absolute_error: 2.6141 - val_root_mean_squared_error: 3.8470
# Epoch 35/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8159 - mean_absolute_error: 0.5910 - root_mean_squared_error: 0.9033 - val_loss: 14.8679 - val_mean_absolute_error: 2.6173 - val_root_mean_squared_error: 3.8559
# Epoch 36/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7887 - mean_absolute_error: 0.5802 - root_mean_squared_error: 0.8881 - val_loss: 14.6681 - val_mean_absolute_error: 2.6031 - val_root_mean_squared_error: 3.8299
# Epoch 37/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7570 - mean_absolute_error: 0.5658 - root_mean_squared_error: 0.8700 - val_loss: 14.4286 - val_mean_absolute_error: 2.5858 - val_root_mean_squared_error: 3.7985
# Epoch 38/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7260 - mean_absolute_error: 0.5514 - root_mean_squared_error: 0.8520 - val_loss: 14.2889 - val_mean_absolute_error: 2.5733 - val_root_mean_squared_error: 3.7801
# Epoch 39/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6967 - mean_absolute_error: 0.5382 - root_mean_squared_error: 0.8347 - val_loss: 14.2690 - val_mean_absolute_error: 2.5673 - val_root_mean_squared_error: 3.7774
# Epoch 40/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6683 - mean_absolute_error: 0.5250 - root_mean_squared_error: 0.8175 - val_loss: 14.3116 - val_mean_absolute_error: 2.5647 - val_root_mean_squared_error: 3.7831
# Epoch 41/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6411 - mean_absolute_error: 0.5119 - root_mean_squared_error: 0.8007 - val_loss: 14.3349 - val_mean_absolute_error: 2.5612 - val_root_mean_squared_error: 3.7861
# Epoch 42/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6157 - mean_absolute_error: 0.4992 - root_mean_squared_error: 0.7847 - val_loss: 14.2601 - val_mean_absolute_error: 2.5503 - val_root_mean_squared_error: 3.7763
# Epoch 43/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5921 - mean_absolute_error: 0.4868 - root_mean_squared_error: 0.7695 - val_loss: 14.0477 - val_mean_absolute_error: 2.5301 - val_root_mean_squared_error: 3.7480
# Epoch 44/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5696 - mean_absolute_error: 0.4741 - root_mean_squared_error: 0.7547 - val_loss: 13.7191 - val_mean_absolute_error: 2.5030 - val_root_mean_squared_error: 3.7039
# Epoch 45/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5479 - mean_absolute_error: 0.4612 - root_mean_squared_error: 0.7402 - val_loss: 13.3471 - val_mean_absolute_error: 2.4722 - val_root_mean_squared_error: 3.6534
# Epoch 46/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5273 - mean_absolute_error: 0.4488 - root_mean_squared_error: 0.7262 - val_loss: 13.0100 - val_mean_absolute_error: 2.4440 - val_root_mean_squared_error: 3.6069
# Epoch 47/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5080 - mean_absolute_error: 0.4377 - root_mean_squared_error: 0.7128 - val_loss: 12.7604 - val_mean_absolute_error: 2.4209 - val_root_mean_squared_error: 3.5722
# Epoch 48/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4897 - mean_absolute_error: 0.4273 - root_mean_squared_error: 0.6998 - val_loss: 12.6161 - val_mean_absolute_error: 2.4049 - val_root_mean_squared_error: 3.5519
# Epoch 49/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4720 - mean_absolute_error: 0.4176 - root_mean_squared_error: 0.6870 - val_loss: 12.5625 - val_mean_absolute_error: 2.3958 - val_root_mean_squared_error: 3.5444
# Epoch 50/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4551 - mean_absolute_error: 0.4090 - root_mean_squared_error: 0.6746 - val_loss: 12.5500 - val_mean_absolute_error: 2.3894 - val_root_mean_squared_error: 3.5426
# Epoch 51/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4394 - mean_absolute_error: 0.4013 - root_mean_squared_error: 0.6629 - val_loss: 12.5131 - val_mean_absolute_error: 2.3814 - val_root_mean_squared_error: 3.5374
# Epoch 52/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4248 - mean_absolute_error: 0.3935 - root_mean_squared_error: 0.6517 - val_loss: 12.3989 - val_mean_absolute_error: 2.3681 - val_root_mean_squared_error: 3.5212
# Epoch 53/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4108 - mean_absolute_error: 0.3854 - root_mean_squared_error: 0.6409 - val_loss: 12.1982 - val_mean_absolute_error: 2.3483 - val_root_mean_squared_error: 3.4926
# Epoch 54/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3974 - mean_absolute_error: 0.3768 - root_mean_squared_error: 0.6304 - val_loss: 11.9467 - val_mean_absolute_error: 2.3253 - val_root_mean_squared_error: 3.4564
# Epoch 55/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3849 - mean_absolute_error: 0.3681 - root_mean_squared_error: 0.6204 - val_loss: 11.7017 - val_mean_absolute_error: 2.3028 - val_root_mean_squared_error: 3.4208
# Epoch 56/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3734 - mean_absolute_error: 0.3594 - root_mean_squared_error: 0.6111 - val_loss: 11.5052 - val_mean_absolute_error: 2.2840 - val_root_mean_squared_error: 3.3919
# Epoch 57/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3627 - mean_absolute_error: 0.3517 - root_mean_squared_error: 0.6022 - val_loss: 11.3713 - val_mean_absolute_error: 2.2702 - val_root_mean_squared_error: 3.3721
# Epoch 58/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3525 - mean_absolute_error: 0.3445 - root_mean_squared_error: 0.5937 - val_loss: 11.2845 - val_mean_absolute_error: 2.2604 - val_root_mean_squared_error: 3.3592
# Epoch 59/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3430 - mean_absolute_error: 0.3378 - root_mean_squared_error: 0.5857 - val_loss: 11.2088 - val_mean_absolute_error: 2.2518 - val_root_mean_squared_error: 3.3479
# Epoch 60/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3342 - mean_absolute_error: 0.3309 - root_mean_squared_error: 0.5781 - val_loss: 11.1103 - val_mean_absolute_error: 2.2417 - val_root_mean_squared_error: 3.3332
# Epoch 61/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3259 - mean_absolute_error: 0.3238 - root_mean_squared_error: 0.5709 - val_loss: 10.9770 - val_mean_absolute_error: 2.2291 - val_root_mean_squared_error: 3.3131
# Epoch 62/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3180 - mean_absolute_error: 0.3173 - root_mean_squared_error: 0.5639 - val_loss: 10.8318 - val_mean_absolute_error: 2.2158 - val_root_mean_squared_error: 3.2912
# Epoch 63/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3106 - mean_absolute_error: 0.3109 - root_mean_squared_error: 0.5573 - val_loss: 10.7089 - val_mean_absolute_error: 2.2048 - val_root_mean_squared_error: 3.2724
# Epoch 64/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3038 - mean_absolute_error: 0.3050 - root_mean_squared_error: 0.5512 - val_loss: 10.6330 - val_mean_absolute_error: 2.1977 - val_root_mean_squared_error: 3.2608
# Epoch 65/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2975 - mean_absolute_error: 0.3001 - root_mean_squared_error: 0.5454 - val_loss: 10.6106 - val_mean_absolute_error: 2.1951 - val_root_mean_squared_error: 3.2574
# Epoch 66/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2914 - mean_absolute_error: 0.2956 - root_mean_squared_error: 0.5398 - val_loss: 10.6231 - val_mean_absolute_error: 2.1953 - val_root_mean_squared_error: 3.2593
# Epoch 67/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2856 - mean_absolute_error: 0.2915 - root_mean_squared_error: 0.5344 - val_loss: 10.6415 - val_mean_absolute_error: 2.1962 - val_root_mean_squared_error: 3.2621
# Epoch 68/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2801 - mean_absolute_error: 0.2874 - root_mean_squared_error: 0.5292 - val_loss: 10.6352 - val_mean_absolute_error: 2.1951 - val_root_mean_squared_error: 3.2612
# Epoch 69/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2748 - mean_absolute_error: 0.2834 - root_mean_squared_error: 0.5242 - val_loss: 10.5940 - val_mean_absolute_error: 2.1908 - val_root_mean_squared_error: 3.2548
# Epoch 70/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2697 - mean_absolute_error: 0.2793 - root_mean_squared_error: 0.5193 - val_loss: 10.5353 - val_mean_absolute_error: 2.1851 - val_root_mean_squared_error: 3.2458
# Epoch 71/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2648 - mean_absolute_error: 0.2753 - root_mean_squared_error: 0.5146 - val_loss: 10.4850 - val_mean_absolute_error: 2.1802 - val_root_mean_squared_error: 3.2381
# Epoch 72/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2602 - mean_absolute_error: 0.2716 - root_mean_squared_error: 0.5101 - val_loss: 10.4625 - val_mean_absolute_error: 2.1775 - val_root_mean_squared_error: 3.2346
# Epoch 73/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2558 - mean_absolute_error: 0.2685 - root_mean_squared_error: 0.5057 - val_loss: 10.4708 - val_mean_absolute_error: 2.1775 - val_root_mean_squared_error: 3.2359
# Epoch 74/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2514 - mean_absolute_error: 0.2659 - root_mean_squared_error: 0.5014 - val_loss: 10.4869 - val_mean_absolute_error: 2.1785 - val_root_mean_squared_error: 3.2383
# Epoch 75/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2473 - mean_absolute_error: 0.2637 - root_mean_squared_error: 0.4972 - val_loss: 10.4898 - val_mean_absolute_error: 2.1785 - val_root_mean_squared_error: 3.2388
# Epoch 76/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2432 - mean_absolute_error: 0.2618 - root_mean_squared_error: 0.4931 - val_loss: 10.4636 - val_mean_absolute_error: 2.1764 - val_root_mean_squared_error: 3.2348
# Epoch 77/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2392 - mean_absolute_error: 0.2597 - root_mean_squared_error: 0.4891 - val_loss: 10.4094 - val_mean_absolute_error: 2.1720 - val_root_mean_squared_error: 3.2264
# Epoch 78/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2353 - mean_absolute_error: 0.2573 - root_mean_squared_error: 0.4851 - val_loss: 10.3427 - val_mean_absolute_error: 2.1664 - val_root_mean_squared_error: 3.2160
# Epoch 79/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2315 - mean_absolute_error: 0.2547 - root_mean_squared_error: 0.4811 - val_loss: 10.2833 - val_mean_absolute_error: 2.1612 - val_root_mean_squared_error: 3.2068
# Epoch 80/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2277 - mean_absolute_error: 0.2523 - root_mean_squared_error: 0.4772 - val_loss: 10.2499 - val_mean_absolute_error: 2.1580 - val_root_mean_squared_error: 3.2016
# Epoch 81/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2241 - mean_absolute_error: 0.2500 - root_mean_squared_error: 0.4734 - val_loss: 10.2386 - val_mean_absolute_error: 2.1568 - val_root_mean_squared_error: 3.1998
# Epoch 82/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2205 - mean_absolute_error: 0.2481 - root_mean_squared_error: 0.4695 - val_loss: 10.2346 - val_mean_absolute_error: 2.1560 - val_root_mean_squared_error: 3.1992
# Epoch 83/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2170 - mean_absolute_error: 0.2463 - root_mean_squared_error: 0.4658 - val_loss: 10.2197 - val_mean_absolute_error: 2.1539 - val_root_mean_squared_error: 3.1968
# Epoch 84/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2136 - mean_absolute_error: 0.2443 - root_mean_squared_error: 0.4621 - val_loss: 10.1791 - val_mean_absolute_error: 2.1495 - val_root_mean_squared_error: 3.1905
# Epoch 85/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2102 - mean_absolute_error: 0.2421 - root_mean_squared_error: 0.4585 - val_loss: 10.1258 - val_mean_absolute_error: 2.1440 - val_root_mean_squared_error: 3.1821
# Epoch 86/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2069 - mean_absolute_error: 0.2398 - root_mean_squared_error: 0.4548 - val_loss: 10.0806 - val_mean_absolute_error: 2.1392 - val_root_mean_squared_error: 3.1750
# Epoch 87/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2037 - mean_absolute_error: 0.2376 - root_mean_squared_error: 0.4513 - val_loss: 10.0645 - val_mean_absolute_error: 2.1368 - val_root_mean_squared_error: 3.1725
# Epoch 88/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2004 - mean_absolute_error: 0.2357 - root_mean_squared_error: 0.4477 - val_loss: 10.0723 - val_mean_absolute_error: 2.1365 - val_root_mean_squared_error: 3.1737
# Epoch 89/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1973 - mean_absolute_error: 0.2340 - root_mean_squared_error: 0.4442 - val_loss: 10.0876 - val_mean_absolute_error: 2.1372 - val_root_mean_squared_error: 3.1761
# Epoch 90/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1942 - mean_absolute_error: 0.2323 - root_mean_squared_error: 0.4406 - val_loss: 10.0919 - val_mean_absolute_error: 2.1370 - val_root_mean_squared_error: 3.1768
# Epoch 91/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1911 - mean_absolute_error: 0.2305 - root_mean_squared_error: 0.4371 - val_loss: 10.0808 - val_mean_absolute_error: 2.1356 - val_root_mean_squared_error: 3.1750
# Epoch 92/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1880 - mean_absolute_error: 0.2286 - root_mean_squared_error: 0.4336 - val_loss: 10.0610 - val_mean_absolute_error: 2.1335 - val_root_mean_squared_error: 3.1719
# Epoch 93/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1850 - mean_absolute_error: 0.2266 - root_mean_squared_error: 0.4301 - val_loss: 10.0386 - val_mean_absolute_error: 2.1316 - val_root_mean_squared_error: 3.1684
# Epoch 94/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1819 - mean_absolute_error: 0.2245 - root_mean_squared_error: 0.4265 - val_loss: 10.0425 - val_mean_absolute_error: 2.1321 - val_root_mean_squared_error: 3.1690
# Epoch 95/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1789 - mean_absolute_error: 0.2227 - root_mean_squared_error: 0.4230 - val_loss: 10.0705 - val_mean_absolute_error: 2.1350 - val_root_mean_squared_error: 3.1734
# Epoch 96/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1760 - mean_absolute_error: 0.2211 - root_mean_squared_error: 0.4195 - val_loss: 10.1004 - val_mean_absolute_error: 2.1382 - val_root_mean_squared_error: 3.1781
# Epoch 97/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1731 - mean_absolute_error: 0.2195 - root_mean_squared_error: 0.4161 - val_loss: 10.1030 - val_mean_absolute_error: 2.1388 - val_root_mean_squared_error: 3.1785
# Epoch 98/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1703 - mean_absolute_error: 0.2178 - root_mean_squared_error: 0.4126 - val_loss: 10.0987 - val_mean_absolute_error: 2.1389 - val_root_mean_squared_error: 3.1778
# Epoch 99/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1675 - mean_absolute_error: 0.2161 - root_mean_squared_error: 0.4092 - val_loss: 10.0961 - val_mean_absolute_error: 2.1392 - val_root_mean_squared_error: 3.1774
# Epoch 100/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1647 - mean_absolute_error: 0.2145 - root_mean_squared_error: 0.4058 - val_loss: 10.1057 - val_mean_absolute_error: 2.1405 - val_root_mean_squared_error: 3.1789
#   5%|████▏                                                                              | 1/20 [00:07<02:23,  7.54s/it]
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.2572 - mean_absolute_error: 0.8397 - root_mean_squared_error: 1.1212 - val_loss: 2.3720 - val_mean_absolute_error: 1.1625 - val_root_mean_squared_error: 1.5401
# Epoch 2/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1890 - mean_absolute_error: 0.8086 - root_mean_squared_error: 1.0904 - val_loss: 2.2877 - val_mean_absolute_error: 1.1364 - val_root_mean_squared_error: 1.5125
# Epoch 3/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1287 - mean_absolute_error: 0.7814 - root_mean_squared_error: 1.0624 - val_loss: 2.2073 - val_mean_absolute_error: 1.1107 - val_root_mean_squared_error: 1.4857
# Epoch 4/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0730 - mean_absolute_error: 0.7564 - root_mean_squared_error: 1.0358 - val_loss: 2.1274 - val_mean_absolute_error: 1.0850 - val_root_mean_squared_error: 1.4586
# Epoch 5/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0190 - mean_absolute_error: 0.7317 - root_mean_squared_error: 1.0095 - val_loss: 2.0449 - val_mean_absolute_error: 1.0583 - val_root_mean_squared_error: 1.4300
# Epoch 6/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9646 - mean_absolute_error: 0.7063 - root_mean_squared_error: 0.9822 - val_loss: 1.9574 - val_mean_absolute_error: 1.0300 - val_root_mean_squared_error: 1.3991
# Epoch 7/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9082 - mean_absolute_error: 0.6795 - root_mean_squared_error: 0.9530 - val_loss: 1.8630 - val_mean_absolute_error: 0.9991 - val_root_mean_squared_error: 1.3649
# Epoch 8/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.8484 - mean_absolute_error: 0.6507 - root_mean_squared_error: 0.9211 - val_loss: 1.7598 - val_mean_absolute_error: 0.9651 - val_root_mean_squared_error: 1.3266
# Epoch 9/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7846 - mean_absolute_error: 0.6196 - root_mean_squared_error: 0.8858 - val_loss: 1.6470 - val_mean_absolute_error: 0.9277 - val_root_mean_squared_error: 1.2834
# Epoch 10/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7166 - mean_absolute_error: 0.5860 - root_mean_squared_error: 0.8465 - val_loss: 1.5248 - val_mean_absolute_error: 0.8863 - val_root_mean_squared_error: 1.2348
# Epoch 11/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6450 - mean_absolute_error: 0.5521 - root_mean_squared_error: 0.8031 - val_loss: 1.3947 - val_mean_absolute_error: 0.8431 - val_root_mean_squared_error: 1.1810
# Epoch 12/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5721 - mean_absolute_error: 0.5218 - root_mean_squared_error: 0.7564 - val_loss: 1.2600 - val_mean_absolute_error: 0.7982 - val_root_mean_squared_error: 1.1225
# Epoch 13/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5024 - mean_absolute_error: 0.4968 - root_mean_squared_error: 0.7088 - val_loss: 1.1283 - val_mean_absolute_error: 0.7522 - val_root_mean_squared_error: 1.0622
# Epoch 14/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4442 - mean_absolute_error: 0.4798 - root_mean_squared_error: 0.6665 - val_loss: 1.0105 - val_mean_absolute_error: 0.7092 - val_root_mean_squared_error: 1.0052
# Epoch 15/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4061 - mean_absolute_error: 0.4730 - root_mean_squared_error: 0.6373 - val_loss: 0.9106 - val_mean_absolute_error: 0.6755 - val_root_mean_squared_error: 0.9543
# Epoch 16/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3746 - mean_absolute_error: 0.4624 - root_mean_squared_error: 0.6121 - val_loss: 0.8247 - val_mean_absolute_error: 0.6415 - val_root_mean_squared_error: 0.9081
# Epoch 17/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3330 - mean_absolute_error: 0.4369 - root_mean_squared_error: 0.5770 - val_loss: 0.7512 - val_mean_absolute_error: 0.6061 - val_root_mean_squared_error: 0.8667
# Epoch 18/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2846 - mean_absolute_error: 0.3998 - root_mean_squared_error: 0.5335 - val_loss: 0.6923 - val_mean_absolute_error: 0.5769 - val_root_mean_squared_error: 0.8320
# Epoch 19/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2392 - mean_absolute_error: 0.3592 - root_mean_squared_error: 0.4891 - val_loss: 0.6486 - val_mean_absolute_error: 0.5561 - val_root_mean_squared_error: 0.8054
# Epoch 20/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2024 - mean_absolute_error: 0.3206 - root_mean_squared_error: 0.4499 - val_loss: 0.6176 - val_mean_absolute_error: 0.5462 - val_root_mean_squared_error: 0.7859
# Epoch 21/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1749 - mean_absolute_error: 0.2901 - root_mean_squared_error: 0.4182 - val_loss: 0.5945 - val_mean_absolute_error: 0.5422 - val_root_mean_squared_error: 0.7710
# Epoch 22/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1547 - mean_absolute_error: 0.2692 - root_mean_squared_error: 0.3934 - val_loss: 0.5752 - val_mean_absolute_error: 0.5399 - val_root_mean_squared_error: 0.7584
# Epoch 23/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1397 - mean_absolute_error: 0.2553 - root_mean_squared_error: 0.3738 - val_loss: 0.5573 - val_mean_absolute_error: 0.5375 - val_root_mean_squared_error: 0.7465
# Epoch 24/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1279 - mean_absolute_error: 0.2461 - root_mean_squared_error: 0.3577 - val_loss: 0.5398 - val_mean_absolute_error: 0.5336 - val_root_mean_squared_error: 0.7347
# Epoch 25/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1183 - mean_absolute_error: 0.2391 - root_mean_squared_error: 0.3439 - val_loss: 0.5231 - val_mean_absolute_error: 0.5282 - val_root_mean_squared_error: 0.7232
# Epoch 26/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1102 - mean_absolute_error: 0.2336 - root_mean_squared_error: 0.3320 - val_loss: 0.5077 - val_mean_absolute_error: 0.5231 - val_root_mean_squared_error: 0.7125
# Epoch 27/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1035 - mean_absolute_error: 0.2290 - root_mean_squared_error: 0.3218 - val_loss: 0.4942 - val_mean_absolute_error: 0.5179 - val_root_mean_squared_error: 0.7030
# Epoch 28/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0980 - mean_absolute_error: 0.2243 - root_mean_squared_error: 0.3130 - val_loss: 0.4820 - val_mean_absolute_error: 0.5119 - val_root_mean_squared_error: 0.6942
# Epoch 29/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0931 - mean_absolute_error: 0.2191 - root_mean_squared_error: 0.3051 - val_loss: 0.4700 - val_mean_absolute_error: 0.5049 - val_root_mean_squared_error: 0.6855
# Epoch 30/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0883 - mean_absolute_error: 0.2124 - root_mean_squared_error: 0.2971 - val_loss: 0.4571 - val_mean_absolute_error: 0.4962 - val_root_mean_squared_error: 0.6761
# Epoch 31/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0832 - mean_absolute_error: 0.2051 - root_mean_squared_error: 0.2885 - val_loss: 0.4433 - val_mean_absolute_error: 0.4859 - val_root_mean_squared_error: 0.6658
# Epoch 32/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0782 - mean_absolute_error: 0.1971 - root_mean_squared_error: 0.2796 - val_loss: 0.4290 - val_mean_absolute_error: 0.4753 - val_root_mean_squared_error: 0.6550
# Epoch 33/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0735 - mean_absolute_error: 0.1892 - root_mean_squared_error: 0.2710 - val_loss: 0.4147 - val_mean_absolute_error: 0.4643 - val_root_mean_squared_error: 0.6440
# Epoch 34/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0695 - mean_absolute_error: 0.1813 - root_mean_squared_error: 0.2636 - val_loss: 0.4008 - val_mean_absolute_error: 0.4534 - val_root_mean_squared_error: 0.6331
# Epoch 35/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0662 - mean_absolute_error: 0.1744 - root_mean_squared_error: 0.2572 - val_loss: 0.3874 - val_mean_absolute_error: 0.4431 - val_root_mean_squared_error: 0.6224
# Epoch 36/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0634 - mean_absolute_error: 0.1685 - root_mean_squared_error: 0.2519 - val_loss: 0.3745 - val_mean_absolute_error: 0.4334 - val_root_mean_squared_error: 0.6119
# Epoch 37/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0610 - mean_absolute_error: 0.1640 - root_mean_squared_error: 0.2470 - val_loss: 0.3621 - val_mean_absolute_error: 0.4243 - val_root_mean_squared_error: 0.6018
# Epoch 38/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0588 - mean_absolute_error: 0.1607 - root_mean_squared_error: 0.2424 - val_loss: 0.3505 - val_mean_absolute_error: 0.4157 - val_root_mean_squared_error: 0.5920
# Epoch 39/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0566 - mean_absolute_error: 0.1577 - root_mean_squared_error: 0.2379 - val_loss: 0.3398 - val_mean_absolute_error: 0.4078 - val_root_mean_squared_error: 0.5829
# Epoch 40/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0545 - mean_absolute_error: 0.1546 - root_mean_squared_error: 0.2334 - val_loss: 0.3304 - val_mean_absolute_error: 0.4005 - val_root_mean_squared_error: 0.5748
# Epoch 41/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0524 - mean_absolute_error: 0.1514 - root_mean_squared_error: 0.2289 - val_loss: 0.3223 - val_mean_absolute_error: 0.3939 - val_root_mean_squared_error: 0.5677
# Epoch 42/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0504 - mean_absolute_error: 0.1481 - root_mean_squared_error: 0.2244 - val_loss: 0.3154 - val_mean_absolute_error: 0.3881 - val_root_mean_squared_error: 0.5616
# Epoch 43/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0484 - mean_absolute_error: 0.1446 - root_mean_squared_error: 0.2199 - val_loss: 0.3096 - val_mean_absolute_error: 0.3830 - val_root_mean_squared_error: 0.5564
# Epoch 44/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0463 - mean_absolute_error: 0.1410 - root_mean_squared_error: 0.2152 - val_loss: 0.3047 - val_mean_absolute_error: 0.3789 - val_root_mean_squared_error: 0.5520
# Epoch 45/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0443 - mean_absolute_error: 0.1371 - root_mean_squared_error: 0.2104 - val_loss: 0.3005 - val_mean_absolute_error: 0.3756 - val_root_mean_squared_error: 0.5482
# Epoch 46/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0422 - mean_absolute_error: 0.1331 - root_mean_squared_error: 0.2055 - val_loss: 0.2968 - val_mean_absolute_error: 0.3732 - val_root_mean_squared_error: 0.5448
# Epoch 47/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0402 - mean_absolute_error: 0.1291 - root_mean_squared_error: 0.2005 - val_loss: 0.2936 - val_mean_absolute_error: 0.3711 - val_root_mean_squared_error: 0.5419
# Epoch 48/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0383 - mean_absolute_error: 0.1254 - root_mean_squared_error: 0.1957 - val_loss: 0.2907 - val_mean_absolute_error: 0.3694 - val_root_mean_squared_error: 0.5392
# Epoch 49/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0365 - mean_absolute_error: 0.1220 - root_mean_squared_error: 0.1911 - val_loss: 0.2879 - val_mean_absolute_error: 0.3674 - val_root_mean_squared_error: 0.5366
# Epoch 50/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0348 - mean_absolute_error: 0.1188 - root_mean_squared_error: 0.1866 - val_loss: 0.2852 - val_mean_absolute_error: 0.3652 - val_root_mean_squared_error: 0.5341
# Epoch 51/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0332 - mean_absolute_error: 0.1158 - root_mean_squared_error: 0.1822 - val_loss: 0.2825 - val_mean_absolute_error: 0.3629 - val_root_mean_squared_error: 0.5315
# Epoch 52/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0316 - mean_absolute_error: 0.1130 - root_mean_squared_error: 0.1777 - val_loss: 0.2798 - val_mean_absolute_error: 0.3603 - val_root_mean_squared_error: 0.5290
# Epoch 53/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0300 - mean_absolute_error: 0.1102 - root_mean_squared_error: 0.1733 - val_loss: 0.2771 - val_mean_absolute_error: 0.3576 - val_root_mean_squared_error: 0.5264
# Epoch 54/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0285 - mean_absolute_error: 0.1075 - root_mean_squared_error: 0.1689 - val_loss: 0.2744 - val_mean_absolute_error: 0.3548 - val_root_mean_squared_error: 0.5239
# Epoch 55/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0271 - mean_absolute_error: 0.1049 - root_mean_squared_error: 0.1646 - val_loss: 0.2718 - val_mean_absolute_error: 0.3520 - val_root_mean_squared_error: 0.5213
# Epoch 56/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0257 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1603 - val_loss: 0.2691 - val_mean_absolute_error: 0.3493 - val_root_mean_squared_error: 0.5187
# Epoch 57/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0244 - mean_absolute_error: 0.1002 - root_mean_squared_error: 0.1561 - val_loss: 0.2663 - val_mean_absolute_error: 0.3466 - val_root_mean_squared_error: 0.5160
# Epoch 58/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0231 - mean_absolute_error: 0.0978 - root_mean_squared_error: 0.1519 - val_loss: 0.2635 - val_mean_absolute_error: 0.3439 - val_root_mean_squared_error: 0.5133
# Epoch 59/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0218 - mean_absolute_error: 0.0952 - root_mean_squared_error: 0.1476 - val_loss: 0.2606 - val_mean_absolute_error: 0.3413 - val_root_mean_squared_error: 0.5105
# Epoch 60/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0206 - mean_absolute_error: 0.0925 - root_mean_squared_error: 0.1434 - val_loss: 0.2578 - val_mean_absolute_error: 0.3386 - val_root_mean_squared_error: 0.5077
# Epoch 61/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0194 - mean_absolute_error: 0.0898 - root_mean_squared_error: 0.1393 - val_loss: 0.2550 - val_mean_absolute_error: 0.3358 - val_root_mean_squared_error: 0.5050
# Epoch 62/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0183 - mean_absolute_error: 0.0871 - root_mean_squared_error: 0.1353 - val_loss: 0.2524 - val_mean_absolute_error: 0.3331 - val_root_mean_squared_error: 0.5024
# Epoch 63/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0172 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1313 - val_loss: 0.2499 - val_mean_absolute_error: 0.3303 - val_root_mean_squared_error: 0.4999
# Epoch 64/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0163 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1276 - val_loss: 0.2476 - val_mean_absolute_error: 0.3276 - val_root_mean_squared_error: 0.4976
# Epoch 65/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0154 - mean_absolute_error: 0.0798 - root_mean_squared_error: 0.1240 - val_loss: 0.2454 - val_mean_absolute_error: 0.3248 - val_root_mean_squared_error: 0.4954
# Epoch 66/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0146 - mean_absolute_error: 0.0777 - root_mean_squared_error: 0.1206 - val_loss: 0.2433 - val_mean_absolute_error: 0.3220 - val_root_mean_squared_error: 0.4933
# Epoch 67/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0138 - mean_absolute_error: 0.0757 - root_mean_squared_error: 0.1175 - val_loss: 0.2412 - val_mean_absolute_error: 0.3192 - val_root_mean_squared_error: 0.4912
# Epoch 68/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0131 - mean_absolute_error: 0.0739 - root_mean_squared_error: 0.1145 - val_loss: 0.2392 - val_mean_absolute_error: 0.3165 - val_root_mean_squared_error: 0.4891
# Epoch 69/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0125 - mean_absolute_error: 0.0721 - root_mean_squared_error: 0.1118 - val_loss: 0.2371 - val_mean_absolute_error: 0.3140 - val_root_mean_squared_error: 0.4869
# Epoch 70/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0119 - mean_absolute_error: 0.0706 - root_mean_squared_error: 0.1092 - val_loss: 0.2351 - val_mean_absolute_error: 0.3117 - val_root_mean_squared_error: 0.4848
# Epoch 71/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0114 - mean_absolute_error: 0.0690 - root_mean_squared_error: 0.1068 - val_loss: 0.2330 - val_mean_absolute_error: 0.3096 - val_root_mean_squared_error: 0.4828
# Epoch 72/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0109 - mean_absolute_error: 0.0674 - root_mean_squared_error: 0.1045 - val_loss: 0.2311 - val_mean_absolute_error: 0.3076 - val_root_mean_squared_error: 0.4807
# Epoch 73/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0105 - mean_absolute_error: 0.0660 - root_mean_squared_error: 0.1023 - val_loss: 0.2292 - val_mean_absolute_error: 0.3057 - val_root_mean_squared_error: 0.4788
# Epoch 74/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0101 - mean_absolute_error: 0.0646 - root_mean_squared_error: 0.1003 - val_loss: 0.2275 - val_mean_absolute_error: 0.3038 - val_root_mean_squared_error: 0.4770
# Epoch 75/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0097 - mean_absolute_error: 0.0633 - root_mean_squared_error: 0.0984 - val_loss: 0.2260 - val_mean_absolute_error: 0.3019 - val_root_mean_squared_error: 0.4754
# Epoch 76/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0093 - mean_absolute_error: 0.0622 - root_mean_squared_error: 0.0966 - val_loss: 0.2247 - val_mean_absolute_error: 0.3002 - val_root_mean_squared_error: 0.4740
# Epoch 77/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0090 - mean_absolute_error: 0.0611 - root_mean_squared_error: 0.0949 - val_loss: 0.2236 - val_mean_absolute_error: 0.2986 - val_root_mean_squared_error: 0.4729
# Epoch 78/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0087 - mean_absolute_error: 0.0600 - root_mean_squared_error: 0.0933 - val_loss: 0.2227 - val_mean_absolute_error: 0.2970 - val_root_mean_squared_error: 0.4719
# Epoch 79/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0084 - mean_absolute_error: 0.0590 - root_mean_squared_error: 0.0917 - val_loss: 0.2220 - val_mean_absolute_error: 0.2957 - val_root_mean_squared_error: 0.4712
# Epoch 80/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0082 - mean_absolute_error: 0.0579 - root_mean_squared_error: 0.0903 - val_loss: 0.2215 - val_mean_absolute_error: 0.2947 - val_root_mean_squared_error: 0.4707
# Epoch 81/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0079 - mean_absolute_error: 0.0569 - root_mean_squared_error: 0.0889 - val_loss: 0.2211 - val_mean_absolute_error: 0.2938 - val_root_mean_squared_error: 0.4702
# Epoch 82/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0077 - mean_absolute_error: 0.0558 - root_mean_squared_error: 0.0876 - val_loss: 0.2207 - val_mean_absolute_error: 0.2931 - val_root_mean_squared_error: 0.4698
# Epoch 83/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0074 - mean_absolute_error: 0.0549 - root_mean_squared_error: 0.0863 - val_loss: 0.2205 - val_mean_absolute_error: 0.2926 - val_root_mean_squared_error: 0.4695
# Epoch 84/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0072 - mean_absolute_error: 0.0540 - root_mean_squared_error: 0.0851 - val_loss: 0.2202 - val_mean_absolute_error: 0.2921 - val_root_mean_squared_error: 0.4693
# Epoch 85/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0071 - mean_absolute_error: 0.0531 - root_mean_squared_error: 0.0840 - val_loss: 0.2200 - val_mean_absolute_error: 0.2917 - val_root_mean_squared_error: 0.4690
# Epoch 86/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0069 - mean_absolute_error: 0.0523 - root_mean_squared_error: 0.0829 - val_loss: 0.2198 - val_mean_absolute_error: 0.2912 - val_root_mean_squared_error: 0.4688
# Epoch 87/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0067 - mean_absolute_error: 0.0516 - root_mean_squared_error: 0.0819 - val_loss: 0.2196 - val_mean_absolute_error: 0.2906 - val_root_mean_squared_error: 0.4686
# Epoch 88/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0066 - mean_absolute_error: 0.0509 - root_mean_squared_error: 0.0810 - val_loss: 0.2194 - val_mean_absolute_error: 0.2899 - val_root_mean_squared_error: 0.4684
# Epoch 89/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0064 - mean_absolute_error: 0.0503 - root_mean_squared_error: 0.0801 - val_loss: 0.2192 - val_mean_absolute_error: 0.2891 - val_root_mean_squared_error: 0.4682
# Epoch 90/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0063 - mean_absolute_error: 0.0497 - root_mean_squared_error: 0.0792 - val_loss: 0.2190 - val_mean_absolute_error: 0.2883 - val_root_mean_squared_error: 0.4680
# Epoch 91/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0061 - mean_absolute_error: 0.0492 - root_mean_squared_error: 0.0784 - val_loss: 0.2188 - val_mean_absolute_error: 0.2875 - val_root_mean_squared_error: 0.4677
# Epoch 92/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0060 - mean_absolute_error: 0.0487 - root_mean_squared_error: 0.0776 - val_loss: 0.2185 - val_mean_absolute_error: 0.2866 - val_root_mean_squared_error: 0.4674
# Epoch 93/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0059 - mean_absolute_error: 0.0481 - root_mean_squared_error: 0.0768 - val_loss: 0.2183 - val_mean_absolute_error: 0.2859 - val_root_mean_squared_error: 0.4672
# Epoch 94/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0058 - mean_absolute_error: 0.0476 - root_mean_squared_error: 0.0760 - val_loss: 0.2180 - val_mean_absolute_error: 0.2851 - val_root_mean_squared_error: 0.4669
# Epoch 95/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0057 - mean_absolute_error: 0.0471 - root_mean_squared_error: 0.0753 - val_loss: 0.2178 - val_mean_absolute_error: 0.2845 - val_root_mean_squared_error: 0.4667
# Epoch 96/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0056 - mean_absolute_error: 0.0466 - root_mean_squared_error: 0.0746 - val_loss: 0.2177 - val_mean_absolute_error: 0.2838 - val_root_mean_squared_error: 0.4666
# Epoch 97/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0055 - mean_absolute_error: 0.0462 - root_mean_squared_error: 0.0739 - val_loss: 0.2176 - val_mean_absolute_error: 0.2832 - val_root_mean_squared_error: 0.4665
# Epoch 98/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0054 - mean_absolute_error: 0.0457 - root_mean_squared_error: 0.0732 - val_loss: 0.2177 - val_mean_absolute_error: 0.2826 - val_root_mean_squared_error: 0.4665
# Epoch 99/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0053 - mean_absolute_error: 0.0452 - root_mean_squared_error: 0.0725 - val_loss: 0.2177 - val_mean_absolute_error: 0.2820 - val_root_mean_squared_error: 0.4666
# Epoch 100/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0052 - mean_absolute_error: 0.0448 - root_mean_squared_error: 0.0718 - val_loss: 0.2177 - val_mean_absolute_error: 0.2814 - val_root_mean_squared_error: 0.4666
#  10%|████████▎                                                                          | 2/20 [00:15<02:16,  7.57s/it]
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.0750 - mean_absolute_error: 1.0730 - root_mean_squared_error: 1.4405 - val_loss: 2.0656 - val_mean_absolute_error: 1.1523 - val_root_mean_squared_error: 1.4372
# Epoch 2/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.9607 - mean_absolute_error: 1.0291 - root_mean_squared_error: 1.4003 - val_loss: 1.9518 - val_mean_absolute_error: 1.1145 - val_root_mean_squared_error: 1.3971
# Epoch 3/100
# ...
# Epoch 33/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1285 - mean_absolute_error: 0.2059 - root_mean_squared_error: 0.3585 - val_loss: 1.7447 - val_mean_absolute_error: 0.7858 - val_root_mean_squared_error: 1.3209
# Epoch 34/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1210 - mean_absolute_error: 0.1989 - root_mean_squared_error: 0.3478 - val_loss: 1.7237 - val_mean_absolute_error: 0.7812 - val_root_mean_squared_error: 1.3129
# Epoch 35/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1141 - mean_absolute_error: 0.1915 - root_mean_squared_error: 0.3378 - val_loss: 1.7029 - val_mean_absolute_error: 0.7763 - val_root_mean_squared_error: 1.3049
# Epoch 36/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1077 - mean_absolute_error: 0.1846 - root_mean_squared_error: 0.3282 - val_loss: 1.6859 - val_mean_absolute_error: 0.7724 - val_root_mean_squared_error: 1.2984
# Epoch 37/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1019 - mean_absolute_error: 0.1784 - root_mean_squared_error: 0.3192 - val_loss: 1.6716 - val_mean_absolute_error: 0.7696 - val_root_mean_squared_error: 1.2929
# Epoch 38/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0967 - mean_absolute_error: 0.1731 - root_mean_squared_error: 0.3110 - val_loss: 1.6546 - val_mean_absolute_error: 0.7656 - val_root_mean_squared_error: 1.2863
# Epoch 39/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0919 - mean_absolute_error: 0.1678 - root_mean_squared_error: 0.3032 - val_loss: 1.6414 - val_mean_absolute_error: 0.7628 - val_root_mean_squared_error: 1.2812
# Epoch 40/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0875 - mean_absolute_error: 0.1631 - root_mean_squared_error: 0.2959 - val_loss: 1.6316 - val_mean_absolute_error: 0.7606 - val_root_mean_squared_error: 1.2773
# Epoch 41/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0835 - mean_absolute_error: 0.1587 - root_mean_squared_error: 0.2890 - val_loss: 1.6196 - val_mean_absolute_error: 0.7571 - val_root_mean_squared_error: 1.2726
# Epoch 42/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0799 - mean_absolute_error: 0.1546 - root_mean_squared_error: 0.2826 - val_loss: 1.6122 - val_mean_absolute_error: 0.7573 - val_root_mean_squared_error: 1.2697
# Epoch 43/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0766 - mean_absolute_error: 0.1507 - root_mean_squared_error: 0.2767 - val_loss: 1.5979 - val_mean_absolute_error: 0.7530 - val_root_mean_squared_error: 1.2641
# Epoch 44/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0736 - mean_absolute_error: 0.1476 - root_mean_squared_error: 0.2712 - val_loss: 1.5959 - val_mean_absolute_error: 0.7553 - val_root_mean_squared_error: 1.2633
# Epoch 45/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0708 - mean_absolute_error: 0.1442 - root_mean_squared_error: 0.2660 - val_loss: 1.5846 - val_mean_absolute_error: 0.7510 - val_root_mean_squared_error: 1.2588
# Epoch 46/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0682 - mean_absolute_error: 0.1413 - root_mean_squared_error: 0.2611 - val_loss: 1.5816 - val_mean_absolute_error: 0.7519 - val_root_mean_squared_error: 1.2576
# Epoch 47/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0657 - mean_absolute_error: 0.1382 - root_mean_squared_error: 0.2563 - val_loss: 1.5793 - val_mean_absolute_error: 0.7527 - val_root_mean_squared_error: 1.2567
# Epoch 48/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0634 - mean_absolute_error: 0.1352 - root_mean_squared_error: 0.2517 - val_loss: 1.5718 - val_mean_absolute_error: 0.7495 - val_root_mean_squared_error: 1.2537
# Epoch 49/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0612 - mean_absolute_error: 0.1323 - root_mean_squared_error: 0.2473 - val_loss: 1.5719 - val_mean_absolute_error: 0.7519 - val_root_mean_squared_error: 1.2538
# Epoch 50/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0590 - mean_absolute_error: 0.1290 - root_mean_squared_error: 0.2429 - val_loss: 1.5683 - val_mean_absolute_error: 0.7509 - val_root_mean_squared_error: 1.2523
# Epoch 51/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0570 - mean_absolute_error: 0.1258 - root_mean_squared_error: 0.2387 - val_loss: 1.5621 - val_mean_absolute_error: 0.7474 - val_root_mean_squared_error: 1.2498
# Epoch 52/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0551 - mean_absolute_error: 0.1229 - root_mean_squared_error: 0.2347 - val_loss: 1.5618 - val_mean_absolute_error: 0.7485 - val_root_mean_squared_error: 1.2497
# Epoch 53/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0532 - mean_absolute_error: 0.1199 - root_mean_squared_error: 0.2307 - val_loss: 1.5556 - val_mean_absolute_error: 0.7456 - val_root_mean_squared_error: 1.2472
# Epoch 54/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0514 - mean_absolute_error: 0.1170 - root_mean_squared_error: 0.2268 - val_loss: 1.5507 - val_mean_absolute_error: 0.7437 - val_root_mean_squared_error: 1.2453
# Epoch 55/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0498 - mean_absolute_error: 0.1143 - root_mean_squared_error: 0.2232 - val_loss: 1.5504 - val_mean_absolute_error: 0.7454 - val_root_mean_squared_error: 1.2451
# Epoch 56/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0483 - mean_absolute_error: 0.1120 - root_mean_squared_error: 0.2197 - val_loss: 1.5435 - val_mean_absolute_error: 0.7425 - val_root_mean_squared_error: 1.2424
# Epoch 57/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0468 - mean_absolute_error: 0.1098 - root_mean_squared_error: 0.2164 - val_loss: 1.5406 - val_mean_absolute_error: 0.7426 - val_root_mean_squared_error: 1.2412
# Epoch 58/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0455 - mean_absolute_error: 0.1077 - root_mean_squared_error: 0.2132 - val_loss: 1.5391 - val_mean_absolute_error: 0.7431 - val_root_mean_squared_error: 1.2406
# Epoch 59/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0442 - mean_absolute_error: 0.1057 - root_mean_squared_error: 0.2102 - val_loss: 1.5334 - val_mean_absolute_error: 0.7399 - val_root_mean_squared_error: 1.2383
# Epoch 60/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0430 - mean_absolute_error: 0.1038 - root_mean_squared_error: 0.2073 - val_loss: 1.5322 - val_mean_absolute_error: 0.7404 - val_root_mean_squared_error: 1.2378
# Epoch 61/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0418 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.2045 - val_loss: 1.5288 - val_mean_absolute_error: 0.7391 - val_root_mean_squared_error: 1.2365
# Epoch 62/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0408 - mean_absolute_error: 0.1003 - root_mean_squared_error: 0.2019 - val_loss: 1.5247 - val_mean_absolute_error: 0.7373 - val_root_mean_squared_error: 1.2348
# Epoch 63/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0398 - mean_absolute_error: 0.0989 - root_mean_squared_error: 0.1994 - val_loss: 1.5247 - val_mean_absolute_error: 0.7389 - val_root_mean_squared_error: 1.2348
# Epoch 64/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0388 - mean_absolute_error: 0.0974 - root_mean_squared_error: 0.1970 - val_loss: 1.5202 - val_mean_absolute_error: 0.7364 - val_root_mean_squared_error: 1.2330
# Epoch 65/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0379 - mean_absolute_error: 0.0960 - root_mean_squared_error: 0.1946 - val_loss: 1.5202 - val_mean_absolute_error: 0.7369 - val_root_mean_squared_error: 1.2330
# Epoch 66/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0370 - mean_absolute_error: 0.0948 - root_mean_squared_error: 0.1923 - val_loss: 1.5183 - val_mean_absolute_error: 0.7363 - val_root_mean_squared_error: 1.2322
# Epoch 67/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0361 - mean_absolute_error: 0.0935 - root_mean_squared_error: 0.1901 - val_loss: 1.5145 - val_mean_absolute_error: 0.7347 - val_root_mean_squared_error: 1.2307
# Epoch 68/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0353 - mean_absolute_error: 0.0922 - root_mean_squared_error: 0.1880 - val_loss: 1.5149 - val_mean_absolute_error: 0.7360 - val_root_mean_squared_error: 1.2308
# Epoch 69/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0346 - mean_absolute_error: 0.0912 - root_mean_squared_error: 0.1859 - val_loss: 1.5105 - val_mean_absolute_error: 0.7335 - val_root_mean_squared_error: 1.2290
# Epoch 70/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0338 - mean_absolute_error: 0.0902 - root_mean_squared_error: 0.1839 - val_loss: 1.5117 - val_mean_absolute_error: 0.7356 - val_root_mean_squared_error: 1.2295
# Epoch 71/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0331 - mean_absolute_error: 0.0891 - root_mean_squared_error: 0.1819 - val_loss: 1.5071 - val_mean_absolute_error: 0.7334 - val_root_mean_squared_error: 1.2276
# Epoch 72/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0324 - mean_absolute_error: 0.0881 - root_mean_squared_error: 0.1799 - val_loss: 1.5079 - val_mean_absolute_error: 0.7349 - val_root_mean_squared_error: 1.2280
# Epoch 73/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0317 - mean_absolute_error: 0.0869 - root_mean_squared_error: 0.1779 - val_loss: 1.5044 - val_mean_absolute_error: 0.7328 - val_root_mean_squared_error: 1.2265
# Epoch 74/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0310 - mean_absolute_error: 0.0859 - root_mean_squared_error: 0.1760 - val_loss: 1.5060 - val_mean_absolute_error: 0.7346 - val_root_mean_squared_error: 1.2272
# Epoch 75/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0303 - mean_absolute_error: 0.0850 - root_mean_squared_error: 0.1741 - val_loss: 1.5012 - val_mean_absolute_error: 0.7322 - val_root_mean_squared_error: 1.2252
# Epoch 76/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0297 - mean_absolute_error: 0.0841 - root_mean_squared_error: 0.1723 - val_loss: 1.5037 - val_mean_absolute_error: 0.7346 - val_root_mean_squared_error: 1.2262
# Epoch 77/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0291 - mean_absolute_error: 0.0831 - root_mean_squared_error: 0.1705 - val_loss: 1.4974 - val_mean_absolute_error: 0.7302 - val_root_mean_squared_error: 1.2237
# Epoch 78/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0285 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1688 - val_loss: 1.5036 - val_mean_absolute_error: 0.7353 - val_root_mean_squared_error: 1.2262
# Epoch 79/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0279 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1672 - val_loss: 1.4930 - val_mean_absolute_error: 0.7281 - val_root_mean_squared_error: 1.2219
# Epoch 80/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0274 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1656 - val_loss: 1.5033 - val_mean_absolute_error: 0.7363 - val_root_mean_squared_error: 1.2261
# Epoch 81/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0269 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1640 - val_loss: 1.4932 - val_mean_absolute_error: 0.7280 - val_root_mean_squared_error: 1.2220
# Epoch 82/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0263 - mean_absolute_error: 0.0789 - root_mean_squared_error: 0.1621 - val_loss: 1.4978 - val_mean_absolute_error: 0.7324 - val_root_mean_squared_error: 1.2239
# Epoch 83/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0256 - mean_absolute_error: 0.0776 - root_mean_squared_error: 0.1600 - val_loss: 1.4949 - val_mean_absolute_error: 0.7308 - val_root_mean_squared_error: 1.2226
# Epoch 84/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0250 - mean_absolute_error: 0.0764 - root_mean_squared_error: 0.1582 - val_loss: 1.4909 - val_mean_absolute_error: 0.7275 - val_root_mean_squared_error: 1.2210
# Epoch 85/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0246 - mean_absolute_error: 0.0762 - root_mean_squared_error: 0.1568 - val_loss: 1.4953 - val_mean_absolute_error: 0.7322 - val_root_mean_squared_error: 1.2228
# Epoch 86/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0241 - mean_absolute_error: 0.0750 - root_mean_squared_error: 0.1553 - val_loss: 1.4890 - val_mean_absolute_error: 0.7262 - val_root_mean_squared_error: 1.2202
# Epoch 87/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0236 - mean_absolute_error: 0.0745 - root_mean_squared_error: 0.1536 - val_loss: 1.4914 - val_mean_absolute_error: 0.7288 - val_root_mean_squared_error: 1.2212
# Epoch 88/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0230 - mean_absolute_error: 0.0730 - root_mean_squared_error: 0.1517 - val_loss: 1.4911 - val_mean_absolute_error: 0.7282 - val_root_mean_squared_error: 1.2211
# Epoch 89/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0225 - mean_absolute_error: 0.0723 - root_mean_squared_error: 0.1501 - val_loss: 1.4879 - val_mean_absolute_error: 0.7252 - val_root_mean_squared_error: 1.2198
# Epoch 90/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0221 - mean_absolute_error: 0.0717 - root_mean_squared_error: 0.1486 - val_loss: 1.4914 - val_mean_absolute_error: 0.7289 - val_root_mean_squared_error: 1.2212
# Epoch 91/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0217 - mean_absolute_error: 0.0708 - root_mean_squared_error: 0.1472 - val_loss: 1.4869 - val_mean_absolute_error: 0.7243 - val_root_mean_squared_error: 1.2194
# Epoch 92/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0212 - mean_absolute_error: 0.0703 - root_mean_squared_error: 0.1455 - val_loss: 1.4879 - val_mean_absolute_error: 0.7263 - val_root_mean_squared_error: 1.2198
# Epoch 93/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0207 - mean_absolute_error: 0.0688 - root_mean_squared_error: 0.1439 - val_loss: 1.4877 - val_mean_absolute_error: 0.7255 - val_root_mean_squared_error: 1.2197
# Epoch 94/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0203 - mean_absolute_error: 0.0686 - root_mean_squared_error: 0.1423 - val_loss: 1.4854 - val_mean_absolute_error: 0.7233 - val_root_mean_squared_error: 1.2188
# Epoch 95/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0198 - mean_absolute_error: 0.0673 - root_mean_squared_error: 0.1409 - val_loss: 1.4889 - val_mean_absolute_error: 0.7264 - val_root_mean_squared_error: 1.2202
# Epoch 96/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0194 - mean_absolute_error: 0.0668 - root_mean_squared_error: 0.1394 - val_loss: 1.4857 - val_mean_absolute_error: 0.7224 - val_root_mean_squared_error: 1.2189
# Epoch 97/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0190 - mean_absolute_error: 0.0663 - root_mean_squared_error: 0.1379 - val_loss: 1.4869 - val_mean_absolute_error: 0.7248 - val_root_mean_squared_error: 1.2194
# Epoch 98/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0186 - mean_absolute_error: 0.0648 - root_mean_squared_error: 0.1364 - val_loss: 1.4860 - val_mean_absolute_error: 0.7226 - val_root_mean_squared_error: 1.2190
# Epoch 99/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0182 - mean_absolute_error: 0.0647 - root_mean_squared_error: 0.1348 - val_loss: 1.4859 - val_mean_absolute_error: 0.7230 - val_root_mean_squared_error: 1.2190
# Epoch 100/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0178 - mean_absolute_error: 0.0635 - root_mean_squared_error: 0.1333 - val_loss: 1.4867 - val_mean_absolute_error: 0.7236 - val_root_mean_squared_error: 1.2193

# %%
# results_rak
visualize_performance(results_rak)
# Out:
# Optimal Mean MAE: 0.8860218798741698 @ epoch 62
# Optimal Mean RMSE: 1.3505768528208137 @ epoch 61

# %%
visualize_performance(results_wall)
# Out:
# Optimal Mean MAE: 0.7327585905790329 @ epoch 99
# Optimal Mean RMSE: 1.1691561400890351 @ epoch 99

# %%
visualize_performance(results_total[1])
# Out:
# Optimal Mean MAE: 0.7224365472793579 @ epoch 95
# Optimal Mean RMSE: 1.2187684774398804 @ epoch 93

# %% [markdown]
# ### Tacheometry Only

# %%
results_tcmt_x = train_objects(train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=True)
results_tcmt_y = train_objects(train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=True)
results_tcmt_z = train_objects(train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=True)

# %%
print('RMSE', 'MAE', 'MASE', 'R^2')
print(val_metrics('X', results_tcmt_x[0], 10, 5, 1, incl_cpt=False, incl_sat=False, tacheometry=True, incremental=False))
print(val_metrics('Y', results_tcmt_y[0], 10, 5, 1, incl_cpt=False, incl_sat=False, tacheometry=True, incremental=False))
print(val_metrics('Z', results_tcmt_z[0], 10, 5, 1, incl_cpt=False, incl_sat=False, tacheometry=True, incremental=False))
# Out:
# RMSE MAE MASE R^2
# (1.1123464, 0.7910220931373606, 0.46241750071163273, -98.94533842875592)
# (1.2415555, 0.9062942200515177, 0.39947965419665343, -203.43262710659315)
# (1.0938284, 0.7822483829758522, 0.46088119818515877, -101.85569989344853)

# %%
# Run only if model should be saved AND written over on disk

save_models(results_tcmt_x, 'TCMT', 'X')
save_models(results_tcmt_y, 'TCMT', 'Y')
save_models(results_tcmt_z, 'TCMT', 'Z')

# %% [markdown]
# ### Tacheometry + CPT

# %%
results_tcmt_cpt_x = train_objects(train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=True)
results_tcmt_cpt_y = train_objects(train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=True)
results_tcmt_cpt_z = train_objects(train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:59<00:00,  5.97s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:48<00:00,  5.43s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:51<00:00,  5.58s/it]

# %%
print(val_metrics('X', results_tcmt_cpt_x[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=True, incremental=False))
print(val_metrics('Y', results_tcmt_cpt_y[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=True, incremental=False))
print(val_metrics('Z', results_tcmt_cpt_z[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=True, incremental=False))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D90F3E8F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D90F47DAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.079717, 0.7690374010709731, 0.45759626143273396, -147.38229360916685)
# (1.2133859, 0.8794474722176234, 0.38455018794810086, -189.93629028742072)
# (1.0781837, 0.7685083161720458, 0.4537022831485917, -81.17139777480223)

# %%
save_models(results_tcmt_cpt_x, 'TCMT_CPT', 'X')
save_models(results_tcmt_cpt_y, 'TCMT_CPT', 'Y')
save_models(results_tcmt_cpt_z, 'TCMT_CPT', 'Z')

# %% [markdown]
# ### CPT Only

# %%
results_cpt_x = train_objects(df=train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=False)
results_cpt_y = train_objects(df=train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=False)
results_cpt_z = train_objects(df=train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:56<00:00,  5.83s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:53<00:00,  5.69s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:56<00:00,  5.84s/it]

# %%
print(val_metrics('X', results_cpt_x[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=False, incremental=False))
print(val_metrics('Y', results_cpt_y[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=False, incremental=False))
print(val_metrics('Z', results_cpt_z[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=False, incremental=False))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000017C0CF0BEE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000017C0DFED040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.2007326, 0.8894597393263377, 0.5194469003005332, -55.12418584640358)
# (1.3684523, 1.0026749408437834, 0.42979171496001467, -104.00207470702344)
# (1.2033317, 0.8911757830395732, 0.5206260647003387, -46.77106554815651)

# %%
save_models(results_cpt_x, 'CPT', 'X')
save_models(results_cpt_y, 'CPT', 'Y')
save_models(results_cpt_z, 'CPT', 'Z')

# %% [markdown]
# ### Tacheometry + Satellite

# %%
results_tcmt_sat_x = train_objects(train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=True, incl_sat=True)
results_tcmt_sat_y = train_objects(train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=True, incl_sat=True)
results_tcmt_sat_z = train_objects(train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=True, incl_sat=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:07<00:00,  6.39s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:07<00:00,  6.40s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:20<00:00,  7.02s/it]

# %%
# mean sat
(1.0899403, 0.7853048451211988, 0.4672808486119302, -186.41611210120135)
(1.1782153, 0.8425265915392283, 0.37742732318565236, -186.864965175712)
(1.0714349, 0.7650132613358018, 0.4520611819197759, -95.91826823843361)

# different time series for each direction
(1.167556, 0.8728575300421998, 0.536836693515254, -337.8655388208417)
(1.2435288, 0.932855880636086, 0.44200158305095477, -370.6174862375467)
(1.198489, 0.8946519199655766, 0.5481434827595083, -389.3761095577384)

# %%
print(val_metrics('X', results_tcmt_sat_x[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=True, incremental=False))
print(val_metrics('Y', results_tcmt_sat_y[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=True, incremental=False))
print(val_metrics('Z', results_tcmt_sat_z[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=True, incremental=False))
# Out:
# (1.0759361, 0.7695640892610401, 0.4667609228961605, -128.2736715847969)
# (1.2175939, 0.8787708310145117, 0.3869327622528927, -211.43315100909967)
# (1.0718968, 0.7794821504235587, 0.46300694276848764, -154.62037793741382)

# %%
save_models(results_tcmt_sat_x, 'TCMT_SAT', 'X')
save_models(results_tcmt_sat_y, 'TCMT_SAT', 'Y')
save_models(results_tcmt_sat_z, 'TCMT_SAT', 'Z')

# %% [markdown]
# ### Satellite Only

# %%
results_sat_x = train_objects(train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=False, incl_sat=True)
results_sat_y = train_objects(train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=False, incl_sat=True)
results_sat_z = train_objects(train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=False, tacheometry=False, incl_sat=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:45<00:00,  5.25s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:41<00:00,  5.08s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:41<00:00,  5.05s/it]

# %%
print(val_metrics('X', results_sat_x[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=False, incremental=False))
print(val_metrics('Y', results_sat_y[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=False, incremental=False))
print(val_metrics('Z', results_sat_z[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=False, incremental=False))
# Out:
# (1.0891328, 0.7817181391138291, 0.47379700478226494, -125.38159255306672)
# (1.198049, 0.8553617536854036, 0.3730054145426475, -233.15624342713335)
# (1.127131, 0.8090382617158014, 0.49006679755230326, -112.85932987887944)

# %%
save_models(results_sat_x, 'SAT', 'X')
save_models(results_sat_y, 'SAT', 'Y')
save_models(results_sat_z, 'SAT', 'Z')

# %% [markdown]
# ### Satellite <- CPT (incremental)

# %%
results_inc_sat_cpt_x = incremental_fusion('Sat', 'X')
results_inc_sat_cpt_y = incremental_fusion('Sat', 'Y')
results_inc_sat_cpt_z = incremental_fusion('Sat', 'Z')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [07:01<00:00, 21.07s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [06:55<00:00, 20.77s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [07:15<00:00, 21.79s/it]

# %%
print(val_metrics('X', results_inc_sat_cpt_x[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=False, incremental=True, incremental_first='Sat'))
print(val_metrics('Y', results_inc_sat_cpt_y[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=False, incremental=True, incremental_first='Sat'))
print(val_metrics('Z', results_inc_sat_cpt_z[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=False, incremental=True, incremental_first='Sat'))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000192F7460B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000192F74601F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.1396741, 0.8087201378477987, 0.472999548847005, -47.59166928335976)
# (1.1733396, 0.8454092941997308, 0.3707709720068019, -39.58811461976282)
# (1.1182802, 0.7879284501864934, 0.4591222868717568, -49.75194787332953)

# %%
save_models(results_inc_sat_cpt_x, 'INC_SAT_CPT', 'X')
save_models(results_inc_sat_cpt_y, 'INC_SAT_CPT', 'Y')
save_models(results_inc_sat_cpt_z, 'INC_SAT_CPT', 'Z')

# %% [markdown]
# ### Tacheometry + Satellite <- CPT (incremental)

# %%
results_inc_tcmt_sat_cpt_x = incremental_fusion('Sat', 'X', tacheometry=True)
results_inc_tcmt_sat_cpt_y = incremental_fusion('Sat', 'Y', tacheometry=True)
results_inc_tcmt_sat_cpt_z = incremental_fusion('Sat', 'Z', tacheometry=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:44<00:00,  8.22s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:53<00:00,  8.70s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:47<00:00,  8.36s/it]

# %%
print(val_metrics('X', results_inc_tcmt_sat_cpt_x[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=True, incremental=True, incremental_first='Sat'))
print(val_metrics('Y', results_inc_tcmt_sat_cpt_y[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=True, incremental=True, incremental_first='Sat'))
print(val_metrics('Z', results_inc_tcmt_sat_cpt_z[0], 10, 5, 1, incl_cpt=False, incl_sat=True, tacheometry=True, incremental=True, incremental_first='Sat'))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002BF583870D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002BF00A10160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.0280902, 0.7139260742469816, 0.4189984431285839, -26.922550389280197)
# (1.0541695, 0.7415452627295276, 0.31320062420013284, -20.936573029903535)
# (1.0415981, 0.73136428740907, 0.43158583357207886, -33.63053353374167)

# %%
save_models(results_inc_tcmt_sat_cpt_x, 'INC_TCMT_SAT_CPT', 'X')
save_models(results_inc_tcmt_sat_cpt_y, 'INC_TCMT_SAT_CPT', 'Y')
save_models(results_inc_tcmt_sat_cpt_z, 'INC_TCMT_SAT_CPT', 'Z')

# %% [markdown]
# ### CPT <- Satellite (incremental)

# %%
results_inc_cpt_sat_x = incremental_fusion('CPT', 'X')
results_inc_cpt_sat_y = incremental_fusion('CPT', 'Y')
results_inc_cpt_sat_z = incremental_fusion('CPT', 'Z')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [07:14<00:00, 21.73s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [07:12<00:00, 21.62s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [07:10<00:00, 21.53s/it]

# %%
print(val_metrics('X', results_inc_cpt_sat_x[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=False, incremental=True, incremental_first='CPT'))
print(val_metrics('Y', results_inc_cpt_sat_y[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=False, incremental=True, incremental_first='CPT'))
print(val_metrics('Z', results_inc_cpt_sat_z[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=False, incremental=True, incremental_first='CPT'))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002965799F0D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029600005160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.1304348, 0.8114228990853862, 0.4744135062534095, -53.68312422185485)
# (1.1379614, 0.8154828616924892, 0.3573341103391451, -45.43225253681015)
# (1.1246732, 0.8081005400681753, 0.4746364720724304, -64.37888416388918)

# %%
save_models(results_inc_cpt_sat_x, 'INC_CPT_SAT', 'X')
save_models(results_inc_cpt_sat_y, 'INC_CPT_SAT', 'Y')
save_models(results_inc_cpt_sat_z, 'INC_CPT_SAT', 'Z')

# %% [markdown]
# ### Tacheometry + CPT <- Satellite (incremental)

# %%
results_inc_tcmt_cpt_sat_x = incremental_fusion('CPT', 'X', tacheometry=True)
results_inc_tcmt_cpt_sat_y = incremental_fusion('CPT', 'Y', tacheometry=True)
results_inc_tcmt_cpt_sat_z = incremental_fusion('CPT', 'Z', tacheometry=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:42<00:00,  8.13s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:53<00:00,  8.67s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:47<00:00,  8.38s/it]

# %%
print(val_metrics('X', results_inc_tcmt_cpt_sat_x[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=True, incremental=True, incremental_first='CPT'))
print(val_metrics('Y', results_inc_tcmt_cpt_sat_y[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=True, incremental=True, incremental_first='CPT'))
print(val_metrics('Z', results_inc_tcmt_cpt_sat_z[0], 10, 5, 1, incl_cpt=True, incl_sat=False, tacheometry=True, incremental=True, incremental_first='CPT'))
# Out:
# (1.0469167, 0.7395422620252023, 0.43524892036906637, -36.069896806291204)
# (1.0426397, 0.7336318293896588, 0.3177306102647406, -47.380980906622355)
# (1.039767, 0.7337450801774674, 0.4310670621735876, -35.633977582030795)

# %%
save_models(results_inc_tcmt_cpt_sat_x, 'INC_TCMT_CPT_SAT', 'X')
save_models(results_inc_tcmt_cpt_sat_y, 'INC_TCMT_CPT_SAT', 'Y')
save_models(results_inc_tcmt_cpt_sat_z, 'INC_TCMT_CPT_SAT', 'Z')

# %% [markdown]
# ### Tacheometry + CPT + Satellite

# %%
results_tcmt_cpt_sat_x = train_objects(train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=True, incl_sat=True)
results_tcmt_cpt_sat_y = train_objects(train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=True, incl_sat=True)
results_tcmt_cpt_sat_z = train_objects(train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=True, incl_sat=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:57<00:00,  5.86s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:59<00:00,  5.95s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:01<00:00,  6.07s/it]

# %%
print(val_metrics('X', results_tcmt_cpt_sat_x[0], 10, 5, 1, incl_cpt=True, incl_sat=True, tacheometry=True, incremental=False))
print(val_metrics('Y', results_tcmt_cpt_sat_y[0], 10, 5, 1, incl_cpt=True, incl_sat=True, tacheometry=True, incremental=False))
print(val_metrics('Z', results_tcmt_cpt_sat_z[0], 10, 5, 1, incl_cpt=True, incl_sat=True, tacheometry=True, incremental=False))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001EE0E6E4CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001EE0F805160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.064839, 0.7642070929557855, 0.458182156304324, -108.82370548789042)
# (1.1807091, 0.8558405061917285, 0.38000676630155455, -213.14858136360334)
# (1.072779, 0.7672759368704889, 0.46075788859976213, -129.8708472291498)

# %%
save_models(results_tcmt_cpt_sat_x, 'TCMT_CPT_SAT', 'X')
save_models(results_tcmt_cpt_sat_y, 'TCMT_CPT_SAT', 'Y')
save_models(results_tcmt_cpt_sat_z, 'TCMT_CPT_SAT', 'Z')

# %% [markdown]
# ### CPT + Satellite

# %%
results_cpt_sat_x = train_objects(train_Yx, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=False, incl_sat=True)
results_cpt_sat_y = train_objects(train_Yy, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=False, incl_sat=True)
results_cpt_sat_z = train_objects(train_Yz, input_width=10, label_width=5, shift=1, epochs=100, incl_cpt=True, tacheometry=False, incl_sat=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [03:27<00:00, 10.38s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [03:17<00:00,  9.85s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [03:23<00:00, 10.20s/it]

# %%
print(val_metrics('X', results_cpt_sat_x[0], 10, 5, 1, incl_cpt=True, incl_sat=True, tacheometry=False, incremental=False))
print(val_metrics('Y', results_cpt_sat_y[0], 10, 5, 1, incl_cpt=True, incl_sat=True, tacheometry=False, incremental=False))
print(val_metrics('Z', results_cpt_sat_z[0], 10, 5, 1, incl_cpt=True, incl_sat=True, tacheometry=False, incremental=False))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020F8D7D8C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020EC1824EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1.1249307, 0.8033167219767303, 0.48366546009451994, -110.58584128139839)
# (1.1770685, 0.8586639674056104, 0.3767699439359974, -263.4586832236406)
# (1.1085229, 0.791343165099051, 0.48047803076502715, -108.21871370577078)

# %%
save_models(results_cpt_sat_x, 'CPT_SAT', 'X')
save_models(results_cpt_sat_y, 'CPT_SAT', 'Y')
save_models(results_cpt_sat_z, 'CPT_SAT', 'Z')

# %% [markdown]
# ### Aggregate CPT / Satellite (late fusion)

# %%
results_cpt_x = [load_models('CPT', 'X')]
results_cpt_y = [load_models('CPT', 'Y')]
results_cpt_z = [load_models('CPT', 'Z')]

results_sat_x = [load_models('SAT', 'X')]
results_sat_y = [load_models('SAT', 'Y')]
results_sat_z = [load_models('SAT', 'Z')]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:31<00:00,  1.57s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:33<00:00,  1.69s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:32<00:00,  1.64s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:34<00:00,  1.72s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:32<00:00,  1.63s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:35<00:00,  1.79s/it]

# %%
print(late_fusion(direction='X', tacheometry=False, incremental=False))
print(late_fusion(direction='Y', tacheometry=False, incremental=False))
print(late_fusion(direction='Z', tacheometry=False, incremental=False))
# Out:
# (1.1042538, 0.8030500185192617, 0.4753667516908767)
# (1.2182729, 0.8827686904743551, 0.3796767384731564)
# (1.129487, 0.8212235466237147, 0.48698521091633856)

# %% [markdown]
# ### Aggregate TCMT + CPT / TCMT + Satellite (late fusion)

# %%
results_tcmt_cpt_x = [load_models('TCMT_CPT', 'X')]
results_tcmt_cpt_y = [load_models('TCMT_CPT', 'Y')]
results_tcmt_cpt_z = [load_models('TCMT_CPT', 'Z')]

results_tcmt_sat_x = [load_models('TCMT_SAT', 'X')]
results_tcmt_sat_y = [load_models('TCMT_SAT', 'Y')]
results_tcmt_sat_z = [load_models('TCMT_SAT', 'Z')]

# %%
print(late_fusion(direction='X', tacheometry=True, incremental=False))
print(late_fusion(direction='Y', tacheometry=True, incremental=False))
print(late_fusion(direction='Z', tacheometry=True, incremental=False))

# %% [markdown]
# ### Aggregate CPT <- Satellite / Satellite <- CPT (late fusion)

# %%
results_inc_cpt_sat_x = [load_models('INC_CPT_SAT', 'X')]
results_inc_cpt_sat_y = [load_models('INC_CPT_SAT', 'Y')]
results_inc_cpt_sat_z = [load_models('INC_CPT_SAT', 'Z')]

results_inc_sat_cpt_x = [load_models('INC_SAT_CPT', 'X')]
results_inc_sat_cpt_y = [load_models('INC_SAT_CPT', 'Y')]
results_inc_sat_cpt_z = [load_models('INC_SAT_CPT', 'Z')]

# %%
print(late_fusion(direction='X', tacheometry=False, incremental=True))
print(late_fusion(direction='Y', tacheometry=False, incremental=True))
print(late_fusion(direction='Z', tacheometry=False, incremental=True))

# %% [markdown]
# ### Aggregate TCMT + CPT <- Satellite / TCMT + Satellite <- CPT (late fusion)

# %%
results_inc_tcmt_cpt_sat_x = [load_models('INC_TCMT_CPT_SAT', 'X')]
results_inc_tcmt_cpt_sat_y = [load_models('INC_TCMT_CPT_SAT', 'Y')]
results_inc_tcmt_cpt_sat_z = [load_models('INC_TCMT_CPT_SAT', 'Z')]

results_inc_tcmt_sat_cpt_x = [load_models('INC_TCMT_SAT_CPT', 'X')]
results_inc_tcmt_sat_cpt_y = [load_models('INC_TCMT_SAT_CPT', 'Y')]
results_inc_tcmt_sat_cpt_z = [load_models('INC_TCMT_SAT_CPT', 'Z')]

# %%
print(late_fusion(direction='X', tacheometry=True, incremental=True))
print(late_fusion(direction='Y', tacheometry=True, incremental=True))
print(late_fusion(direction='Z', tacheometry=True, incremental=True))
# Out:
# (1.0321076, 0.7231472958672182, 0.42236383669356947)
# (1.0097909, 0.7027154133716801, 0.3033248562950376)
# (1.0166171, 0.7128378072706564, 0.41419585343476806)

# %% [markdown]
# ### Naive Baseline

# %%
results_naive = train_objects(train_Yx, input_width=10, label_width=5, shift=1, model='naive', incl_cpt=False, tacheometry=True)
results_naive = np.array(results_naive[1])
rmse_naive = results_naive[:,0]
mae_naive = results_naive[:,1]
mase_naive = results_naive[:,2]
print(f'Baseline Naive Method RMSE = {np.mean(rmse_naive)}')
print(f'Baseline Naive Method MAE = {np.mean(mae_naive)}')
print(f'Baseline Naive Method MASE = {np.mean(mase_naive)}')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 135.14it/s]
# Baseline Naive Method RMSE = 1.2479587481526846
# Baseline Naive Method MAE = 1.186652454193377
# Baseline Naive Method MASE = 0.853035866979823

# %%
results_naive = train_objects(train_Yy, input_width=10, label_width=5, shift=1, model='naive', incl_cpt=False, tacheometry=True)
results_naive = np.array(results_naive[1])
rmse_naive = results_naive[:,0]
mae_naive = results_naive[:,1]
mase_naive = results_naive[:,2]
print(f'Baseline Naive Method RMSE = {np.mean(rmse_naive)}')
print(f'Baseline Naive Method MAE = {np.mean(mae_naive)}')
print(f'Baseline Naive Method MASE = {np.mean(mase_naive)}')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 129.04it/s]
# Baseline Naive Method RMSE = 1.7783279529708367
# Baseline Naive Method MAE = 1.7019130578185302
# Baseline Naive Method MASE = 1.0194687556301143

# %%
results_naive = train_objects(train_Yz, input_width=10, label_width=5, shift=1, model='naive', incl_cpt=False, tacheometry=True)
results_naive = np.array(results_naive[1])
rmse_naive = results_naive[:,0]
mae_naive = results_naive[:,1]
mase_naive = results_naive[:,2]
print(f'Baseline Naive Method RMSE = {np.mean(rmse_naive)}')
print(f'Baseline Naive Method MAE = {np.mean(mae_naive)}')
print(f'Baseline Naive Method MASE = {np.mean(mase_naive)}')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 150.33it/s]
# Baseline Naive Method RMSE = 1.2479587481526846
# Baseline Naive Method MAE = 1.186652454193377
# Baseline Naive Method MASE = 0.853035866979823

# %% [markdown]
# # Evaluation

# %%
fig, ax = plt.subplots(figsize=(18,6))

# create x axis labels
x_nums = [i for i in range(len(cpt.columns)+1) if i%4==0]
labels = list(['timeseries value']) + list(cpt.columns)

# plot weights
plt.bar(x=range(len(cpt.columns)+1), height=model.layers[0].get_weights()[0].mean(axis=1))
plt.xticks(x_nums, labels[::4], rotation=90)
plt.title('Mean Weights of BiLSTM models')

plt.show()
